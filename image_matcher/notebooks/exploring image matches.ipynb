# %%
import json
from IPython.display import Image, display
from room_img_matcher import *

# %%
Image(url='http://multimediarepository.amadeus.com/cmr/retrieve/hotel/80F8DFA3EA1642D29B23099EF9D084C1')
# Out:
# <img src="http://multimediarepository.amadeus.com/cmr/retrieve/hotel/80F8DFA3EA1642D29B23099EF9D084C1"/>

# %%
with open('img_matches_good.json') as f:
    goodm = json.load(f)
with open('img_matches_bad.json') as f:
    badm = json.load(f)

# %%
with open('duplicates.json') as f:
    duplicates = json.load(f)

with open('similar.json') as f:
    similar = json.load(f)

# %%
len(duplicates)
# Out:
# 8539

# %%
len(similar)
# Out:
# 646

# %%
new_similar = {k:v for k,v in similar.items() if k not in goodm}

# %%
len(new_similar)
# Out:
# 611

# %%
mismatches = [pairs[i] for i, v in enumerate(best_y_pred != y_true) if v]

# %%
from random import choice

# %%
new_similar = {k:v for k,v in similar.items() if k not in goodm.keys() + badm.keys()}
imga, imgbs = choice(new_similar.items())
imgb = imgbs[0][0]

x = Image(imga) 
y = Image(imgb)
display(x, y)

# %%
goodm[imga] = imgb
len(goodm)
# Out:
# 100

# %%
badm[imga] = imgb
len(badm)
# Out:
# 50

# %%
with open('img_matches_good.json','w') as f:
    json.dump(goodm,f)
with open('img_matches_bad.json', 'w') as f:
    json.dump(badm,f)
