# %%
# %load_ext autoreload
# %autoreload 2

from excel_matches_livingscores import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. load matches

# %%
with open('matches_excel.json') as f:
    matches = json.load(f)
print(len(matches))
# Out:
# 91035

# %% [markdown]
# # 2. Load Booking data

# %%
print("Loading Booking hotels")
bkgh = load_booking(matches.values())
print(len(bkgh))
# Out:
# Loading Booking hotels
# 91035

# %% [markdown]
# # 2.b Load Amadeus spreadsheet

# %%
print("Loading Amadeus hotels")
amdh_full = pd.read_excel('./Amadeus All Properties - FEB 2017 17022017 .xlsx', header=0, index_col='PROPERTY_CODE', skiprows=1)
amdh = convert_amd_df_to_matching_format(amdh_full)
amdh.amd_id = amdh.amd_id.values.astype(str)
def pc_to_bkg(pc):
    return matches.get(pc)
amdh['bkg_id'] = amdh['amd_id'].apply(pc_to_bkg)

namdh = len(amdh)
print("Loaded %d hotels" % namdh)
# Out:
# Loading Amadeus hotels
# Loaded 140709 hotels

# %% [markdown]
# # 3. Inspect chain matches

# %%
# Don't compute them again: chain_matches_excel.json has been edited with manually checked matches
get_chain_matches(amdh, bkgh, matches)
# Out:
# {u'AC HOTELES': defaultdict(int,
#              {u'AC Hotels by Marriott': 50,
#               u'Aloft': 1,
#               u'Blue Bay Resorts': 1,
#               u'Copthorne Hotels': 1,
#               u'Courtyard by Marriott': 1,
#               u'Hyatt Place': 1,
#               u'Hyatt house': 1,
#               u'JW Marriott Hotels & Resorts': 2,
#               u'Marriott Hotels & Resorts': 1,
#               u'NH Hotels': 2,
#               'NONE': 8,
#               u'Residence Inn': 2,
#               u'SB Hotels': 1,
#               u'VP Hotels': 1,
#               u'Westin': 1}),
#  u'ACCOR HOTELS': defaultdict(int,
#              {u'Adagio Access Aparthotels': 38,
#               u'Adagio Aparthotels': 24,
#               u'Agon Group, ibis Styles': 1,
#               u'B&amp;B Hotels': 5,
#               u'Best Western': 1,
#               u'Caesar Hotels': 1,
#               u'Campanile': 2,
#               u'Cerise Hotels &amp; Residences': 1,
#               u'City Express Hotels': 1,
#               u'Courtyard by Marriott': 2,
#               u'Design Hotels': 1,
#               u'FabHotels': 1,
#               u'Fasthotel': 1,
#               u'Focus Hotel Group, ibis Styles': 1,
#               u'Grand Mercure': 17,
#               u'Grupo Posadas, One Hotels': 1,
#               u'Hanting Inns & Hotels': 2,
#               u'Happyculture, ibis Styles': 1,
#               u'Hi Inn': 2,
#               u'Hilton Hotels & Resorts': 1,
#               u'HipHop Hostels': 1,
#               u'Holiday Inn Express': 1,
#               u'Holiday Inn Hotels & Resorts': 1,
#               u'Home Inn': 2,
#               u'Hotansa': 1,
#               u'Hotel Indigo': 3,
#               u'Ilunion Hotels': 1,
#               u'Kyriad Hotel': 3,
#               u'Les H\xf4tels de Paris': 1,
#               u'MGallery by Sofitel': 7,
#               u'Maeva': 1,
#               u'Mama Shelter': 3,
#               u'Meininger Hotels': 1,
#               u'Meli\xe1 Hotels &amp; Resorts': 1,
#               u'Mercure': 460,
#               u'Mister Bed': 1,
#               u'Mitchells and Butlers Innkeepers lodge': 1,
#               u'Motel One': 4,
#               u'NH Hotels': 1,
#               'NONE': 94,
#               u'Novotel': 285,
#               u'Novotel Suites': 31,
#               u'Oakwood Residence': 1,
#               u'Oberoi Hotels &amp; Resorts': 1,
#               u'Premier Apartments': 1,
#               u'Premier Inn': 2,
#               u'Premiere Classe': 2,
#               u'Principal Hayley Hotels &amp; Conference Venues': 1,
#               u'Pullman Hotels and Resorts': 1,
#               u'Radisson Blu': 2,
#               u'Ramada': 1,
#               u'Renaissance Hotels &amp; Resorts': 1,
#               u'Santika Indonesia Hotels &amp; Resorts': 1,
#               u'Starway Hotels': 1,
#               u'The Sebel': 1,
#               u'Timhotel': 1,
#               u'U Hotels &amp; Resorts': 1,
#               u'[Plateno Hotels Group] 7Days Inn': 1,
#               u'all seasons (Accor)': 3,
#               u'hotelF1': 2,
#               u'ibis': 673,
#               u'ibis Budget': 112,
#               u'ibis Styles': 205,
#               u'ibis Styles, Emirates whitelabel preferred properties': 1}),
#  u'ALESIA DISTRIBUTION': defaultdict(int,
#              {u'AM Resorts': 24,
#               u'Americas Best Inn': 2,
#               u'Apogia Hotel Group': 3,
#               u'Atrium Hotels': 1,
#               u'Charme e Relax': 1,
#               u'Chateaux et Hotels Collection': 1,
#               u'Compagnie des hotels': 1,
#               u'Concerto Hotels': 2,
#               u'Dedeman Hotels': 10,
#               u'Design Hotels': 1,
#               u'Domina Hotels &amp; Resorts': 3,
#               u'Electra Hotels &amp; Resorts': 1,
#               u'Greentree Inn': 2,
#               u'HNA hotel group': 1,
#               u'Hanting Inns & Hotels': 1,
#               u'Hilton Hotels & Resorts': 1,
#               u'Holiday Inn Express': 1,
#               u'Hotels in Venice': 1,
#               u'IDEA HOTEL': 6,
#               u'ITDC Group': 1,
#               u'ITI Hotels': 6,
#               u'Jin Jiang Hotels': 3,
#               u'MC HOTELS COLLECTION': 1,
#               u'Mada Hotels': 2,
#               u'Manxin': 1,
#               u'MiniHotels': 1,
#               'NONE': 711,
#               u'Planetaria Hotels': 2,
#               u'Quality Inn': 1,
#               u'Ramada': 1,
#               u'Red Lion Hotels, Country Hearth Inn &amp; Suites': 2,
#               u'Sina Hotels': 1,
#               u'Super 8': 2,
#               u'Supranational': 1,
#               u'Vatica': 1,
#               u'Vienna Hotel': 2,
#               u'Vienna International Hotels': 2,
#               u'Wyndham Hotels &amp; Resorts': 1,
#               u'[Plateno Hotels Group] 7Days Inn': 1}),
#  u'ALLEGIANCE SERVICES': defaultdict(int, {u'Omni Hotels': 1}),
#  u'ALOFT HOTELS': defaultdict(int,
#              {u'Aloft': 21,
#               u'Howard Johnson': 1,
#               u'Marco Polo Hotels': 1,
#               u'Motel One': 1,
#               u'Novotel': 1,
#               u'Sheraton': 1}),
#  u'AMADEUS LINKHOTEL': defaultdict(int,
#              {u'Abba Hoteles': 12,
#               u'Angsana Hotels &amp; Resorts': 1,
#               u'B&amp;B Hotels': 2,
#               u'Brit Hotel Privil\xe8ge': 1,
#               u'B\xfchlmann Hotels': 1,
#               u'Charles Home': 1,
#               u'Citotel': 1,
#               u'Civitel Hotels &amp; Resorts': 2,
#               u'Classic Norway': 1,
#               u'Countryside Hotels': 1,
#               u'Design Hotels': 1,
#               u'Finlandia Hotels': 1,
#               u'Flair Hotels': 1,
#               u'Hoteles Plaza Andorra': 1,
#               u'Hoteles Porcel': 1,
#               u'ITDC Group': 2,
#               u'Interholiday': 1,
#               u'Interhome': 1,
#               u'Jadranka Hoteli': 3,
#               u'Lagrange': 2,
#               u'Mercure': 1,
#               u'Mogador Hotels &amp; Resorts': 2,
#               u'Motel One': 1,
#               u'NH Hotels': 1,
#               'NONE': 474,
#               u'Novotel': 1,
#               u'OCA Hotels': 1,
#               u'P-Hotels': 1,
#               u'Raphael Hotels': 1,
#               u'Residhotel': 9,
#               u'Rimini Residence': 1,
#               u'Romantik, Raphael Hotels': 1,
#               u'Saimaan Charmantit': 2,
#               u'Smart hotels': 3,
#               u'Svenska Turistf\xf6reningen': 1,
#               u'Thon Hotels, Thon City': 1,
#               u'Timhotel': 1,
#               u'Travelopo': 2,
#               u'VOI hotels': 1,
#               u'Victoria Garden': 1,
#               u'Zenit Hoteles': 11}),
#  u'ANA HOTELS': defaultdict(int,
#              {u'InterContinental Hotels &amp; Resorts': 1}),
#  u'ANDRE BALAZS PROP.': defaultdict(int,
#              {u'Design Hotels, Standard Hotels': 1, 'NONE': 6}),
#  u'AQUA HOTELS AND RSTS': defaultdict(int, {u'Aqua Resorts': 16, 'NONE': 1}),
#  u'ARMANI HOTELS': defaultdict(int,
#              {u'Bulgari Hotels and Resorts': 1, 'NONE': 1}),
#  u'ASCEND COLLECTION': defaultdict(int,
#              {u'Ascend Collection': 80,
#               u'Ascend Collection, Bluegreen Resorts': 7,
#               u'Clarion': 1,
#               u'Comfort Suites': 1,
#               'NONE': 5,
#               u'Sterling Hotels, Ascend Collection': 1,
#               u'Whitehouse Hotels, Ascend Collection': 1,
#               u'Worldhotels, Ascend Collection, Bluegreen Resorts': 6}),
#  u'ASCOTT LIMITED': defaultdict(int,
#              {u'Ascott The Residence': 14,
#               u'Citadines': 45,
#               'NONE': 4,
#               u'Other Residence (Managed by Ascott)': 2,
#               u'Somerset': 24,
#               u'The Crest Collection': 3,
#               u'ibis': 1}),
#  u'ASTON HOTELS': defaultdict(int,
#              {u'Aston Hotels &amp; Resorts': 18,
#               u'Castle Resorts &amp; Hotels': 1,
#               'NONE': 2,
#               u'Omni Hotels': 1}),
#  u'ATEL HOTELS NETWORK': defaultdict(int,
#              {u'A-hotel': 3,
#               u'Accent Hotels, Best Western Plus': 1,
#               u'Adonis': 8,
#               u'Akena Hotel': 1,
#               u'B&amp;B Hotels': 1,
#               u'Belhotel Hotels &amp; Resorts': 1,
#               u'Brit Hotel Confort': 42,
#               u'Brit Hotel Essentiel': 5,
#               u'Brit Hotel Privil\xe8ge': 6,
#               u'Campanile': 1,
#               u'Cerise Hotels &amp; Residences': 5,
#               u'Chateaux et Hotels Collection': 1,
#               u'Citotel': 2,
#               u'Elegancia': 6,
#               u'Exclusive Hotels': 2,
#               u'Friendly Rentals': 1,
#               u'Hotels &amp; Preference': 1,
#               u'H\xf4tels de Charme et de Caract\xe8re': 1,
#               u'Inter-hotel': 1,
#               u'Interhome': 1,
#               u'Kyriad Hotel': 2,
#               u'Lagrange': 1,
#               u'Logis International': 10,
#               u'Mercure': 1,
#               'NONE': 523,
#               u'Newhotel': 1,
#               u'Pierre &amp; Vacances': 8,
#               u'Pierre &amp; Vacances Premium': 2,
#               u'Quality Lodgings': 1,
#               u'Regetel': 1,
#               u'Residhotel': 4,
#               u'Sunotel': 1,
#               u'Swiss Budget Hotels, Brit Hotel Confort': 1,
#               u'The Lodge Group': 1,
#               u'Timhotel': 1,
#               u'Travelopo': 1,
#               u'Villages Clubs': 2}),
#  u'AUTOGRAPH COLLECTION': defaultdict(int,
#              {u'Aloft': 1,
#               u'Autograph Collection': 49,
#               u'Autograph Collection, Destination hotels': 1,
#               u'Autograph Collection, Historic Hotels of America': 1,
#               u'Boscolo Luxury Hotels, Autograph Collection': 1,
#               u'Marriott Hotels & Resorts': 2,
#               'NONE': 17,
#               u'Nau Hotels &amp; Resorts': 1,
#               u'Renaissance Hotels &amp; Resorts': 1,
#               u'The Ritz-Carlton Company, L.L.C': 1}),
#  u'BACCARAT AND 1 HTLS': defaultdict(int, {'NONE': 4}),
#  u'BALLADINS': defaultdict(int,
#              {u'Balladins': 22,
#               u'Balladins Confort': 16,
#               u'Balladins Express': 8,
#               u'Balladins Superior': 10,
#               u'Best Western': 1,
#               u'Holiday Inn Express': 1,
#               u'Kyriad Hotel': 1,
#               'NONE': 6,
#               u'ibis': 1}),
#  u'BANYAN TREE': defaultdict(int,
#              {u'Angsana Hotels &amp; Resorts': 3,
#               u'Banyan Tree Hotels &amp; Resorts': 9,
#               'NONE': 1}),
#  u'BARCELO HOTELS': defaultdict(int,
#              {u'Allegro Hotels Resorts by Barcelo Hotel Group': 2,
#               u'Barcel\xf3 Hotels &amp; Resorts': 41,
#               u'Iberostar Hotels &amp; Resorts': 1,
#               'NONE': 6,
#               u'Occidental Hotels and Resorts by Barcelo Hotel Group': 28,
#               u'Royal Hideway Luxury Hotels by Barcelo Hotel Group': 1,
#               u'Sheraton': 1}),
#  u'BAYMONT INNS': defaultdict(int,
#              {u'Baymont Inn &amp; Suites': 293,
#               u'Country Inns &amp; Suites': 1,
#               u'Days Inn': 8,
#               u'Econo Lodge': 2,
#               u'Fairfield Inn': 1,
#               u'Hampton by Hilton': 4,
#               u'Holiday Inn Express': 3,
#               u'Holiday Inn Hotels & Resorts': 2,
#               u'Hyatt': 1,
#               u'La Quinta Inn and Suites': 3,
#               u'Main Stay Suites': 1,
#               u'Motel6': 1,
#               'NONE': 6,
#               u'Quality Inn': 3,
#               u'Ramada': 2,
#               u'Residence Inn': 1,
#               u'Sleep Inn': 1,
#               u'Wyndham Hotels &amp; Resorts': 7}),
#  u'BELMOND': defaultdict(int, {u'Belmond Hotels': 13, 'NONE': 3}),
#  u'BENCHMARK HTLS': defaultdict(int, {'NONE': 13}),
#  u'BEST WESTERN': defaultdict(int,
#              {u'Amedia Hotels, Best Western Plus': 1,
#               u'Aston International Hotels, Resorts &amp; Residences': 1,
#               u'BW Premier Collection': 4,
#               u'Best Western': 1425,
#               u'Best Western Plus': 647,
#               u'Best Western Plus, WJW Hospitality': 1,
#               u'Best Western Premier': 73,
#               u'Centro Hotel Group': 1,
#               u'Citadines': 1,
#               u'City Express Hotels': 1,
#               u'Clayton': 1,
#               u'Comfort Suites': 4,
#               u'Days Inn': 5,
#               u'Derag Livinghotel, Best Western Premier': 1,
#               u'Econo Lodge': 2,
#               u'Fairfield Inn, Shaner Hotels': 1,
#               u'Hilton Hotels & Resorts': 1,
#               u'Holiday Inn Express': 1,
#               u'Homewood Suites by Hilton': 1,
#               u'La Quinta Inn and Suites': 2,
#               u'Legacy Hotels, Best Western Plus': 1,
#               u'Loews Hotels': 1,
#               u'Motel6': 11,
#               'NONE': 103,
#               u'Nova Hotels': 1,
#               u'Novina Hotels, Best Western Premier': 1,
#               u'Portfolio Hotels, Best Western Plus': 1,
#               u'Premier Inn': 1,
#               u'Prestige, Best Western Plus': 1,
#               u'Principal Hayley Hotels &amp; Conference Venues': 1,
#               u'Ramada': 1,
#               u'Raphael Hotels, Best Western Plus': 1,
#               u'Red Roof Inn': 2,
#               u'Regardz, Best Western Plus': 1,
#               u'Residence Inn': 2,
#               u'Rodeway Inn': 1,
#               u'Sleep Inn': 1,
#               u'Sonesta Collection Hotels': 1,
#               u'St. James Hotel Group': 1,
#               u'Super 8': 18,
#               u'Terme Maribor, Best Western Plus': 1,
#               u'W Hotels': 2,
#               u'WJW Hospitality, BW Premier Collection': 1,
#               u'Westin': 2,
#               u'Wyndham Hotels &amp; Resorts': 2,
#               u'ibis': 2}),
#  u'BKG SVCS BY TRUST': defaultdict(int,
#              {u'AKZENT Hotels': 42,
#               u'Amari Hotels &amp; Resorts': 7,
#               u'AmericInn': 124,
#               u'B&amp;B Hotels': 2,
#               u'Centerhotels': 6,
#               u'Classic British Hotels': 1,
#               u'Comfort Inn': 1,
#               u'Constance Hotels': 1,
#               u'Coral International Hotels , Resorts &amp; Spas': 6,
#               u'Days Inn': 2,
#               u'Econo Lodge': 3,
#               u'Epoque Hotels': 1,
#               u'Falkensteiner Hotels &amp; Residences': 19,
#               u'Hampton by Hilton': 2,
#               u'Holiday Inn Express': 2,
#               u'Holiday Inn Hotels & Resorts': 2,
#               u'Iberostar Hotels &amp; Resorts': 30,
#               u'Iberostar The Grand Collection': 4,
#               u'Interholiday': 1,
#               u'Knights Inn': 1,
#               u'Land-gut-Hotels': 2,
#               u'Landidyll': 2,
#               u'Le Meridien Hotels &amp; Resorts': 1,
#               u'Meininger Hotels': 5,
#               u'Monrif Hotels': 3,
#               u'Motel One': 38,
#               u'NH Hotels': 2,
#               'NONE': 191,
#               u'Nestor Hotels': 3,
#               u'Novotel': 1,
#               u'Ol\xe9 Hoteles': 1,
#               u'Onyx Hospitality Group': 8,
#               u'Onyx Hospitality Group, Amari Hotels &amp; Resorts': 1,
#               u'Quality Inn': 1,
#               u'RIHGA Royal Hotel': 1,
#               u'Ramada': 1,
#               u'Ringhotels': 67,
#               u'Ringhotels, Landidyll': 1,
#               u'Robinson Club': 1,
#               u'Romantik': 12,
#               u'Romantik, PrivateCityHotels.': 1,
#               u'SAJ Hotels&amp; Resorts': 1,
#               u'Safir Hotels': 5,
#               u'Sorell Hotels': 13,
#               u'Super 8': 4,
#               u'Worldhotels': 1,
#               u'mD Hotel Kooperation': 4,
#               u'welcome hotels &amp; restaurants': 9}),
#  u'BOSCOLO HOTELS': defaultdict(int,
#              {u'B4 Hotels': 1, u'Boscolo Luxury Hotels': 1, 'NONE': 1}),
#  u'BRAZIL HOSP GROUP': defaultdict(int, {u'BHG': 6}),
#  u'BULGARI HOTELS': defaultdict(int, {u'Bulgari Hotels and Resorts': 1}),
#  u'BUSINESS TVL ADV.': defaultdict(int,
#              {u'Ascend Collection': 1,
#               u'Hard Rock': 1,
#               u'Hostelling International USA': 1,
#               u'Interhome': 1,
#               u'Motel6': 1,
#               'NONE': 59,
#               u'Oxford Hotel Group': 16,
#               u'Station Casino': 9,
#               u'Swiss Premium Hotels': 1}),
#  u'CAMBRIA SUITES': defaultdict(int,
#              {u'Cambria Suites': 17,
#               u'Cambria Suites, Aimbridge Hospitality': 1,
#               u'Country Inns &amp; Suites': 1,
#               u'Crowne Plaza Hotels &amp; Resorts': 1,
#               u'Embassy Suites Hotels': 1,
#               u'Hampton by Hilton': 1,
#               u'Hilton Garden Inn': 1,
#               u'Residence Inn': 1}),
#  u'CAMINO REAL': defaultdict(int,
#              {u'Camino Real': 23, u'Grupo Posadas, One Hotels': 1, 'NONE': 2}),
#  u'CANDLEWOOD SUITES': defaultdict(int,
#              {u'Candlewood Suites': 280,
#               u'Comfort Inn': 2,
#               u'Courtyard by Marriott': 1,
#               u'Days Inn': 1,
#               u'Drury': 1,
#               u'Hampton by Hilton': 2,
#               u'Holiday Inn Express': 3,
#               u'Holiday Inn Hotels & Resorts': 1,
#               u'Homewood Suites by Hilton': 1,
#               u'Main Stay Suites': 1,
#               u'Motel6': 1,
#               u'Ramada': 1}),
#  u'CHATEAUX&hOTELS COLL': defaultdict(int,
#              {u'Chateaux et Hotels Collection': 62,
#               u'Chateaux et Hotels Collection, H\xf4tels de Charme et de Caract\xe8re': 2,
#               u'Exclusive Hotels': 2,
#               u'H\xf4tels de Charme et de Caract\xe8re': 1,
#               u'Inter-hotel': 1,
#               'NONE': 72}),
#  u'CHIC COLLECTION': defaultdict(int, {'NONE': 2}),
#  u'CITY EXPRESS HOTELS': defaultdict(int,
#              {u'City Express Hotels': 73,
#               u'City Junior': 8,
#               u'Grupo Posadas, One Hotels': 1,
#               u'Holiday Inn Express': 1,
#               'NONE': 5,
#               u'ibis': 1}),
#  u'CITY LODGE HOTELS': defaultdict(int, {'NONE': 1}),
#  u'CITY PARTNER HOTELS': defaultdict(int, {u'City Partner': 21, 'NONE': 10}),
#  u'CLARION HOTELS': defaultdict(int,
#              {u'Akkeron Hotels, Clarion Collection': 2,
#               u'Clarion': 149,
#               u'Clarion Collection': 2,
#               u'Clarion, Aimbridge Hospitality': 1,
#               u'Clarion, Continental Hotels': 1,
#               u'Clarion, GF Hotels': 1,
#               u'Clarion, Maldron': 1,
#               u'Clarion, Nordic Choice Hotels': 15,
#               u'Comfort Inn': 3,
#               u'Days Inn': 2,
#               u'Econo Lodge': 1,
#               u'Hampton by Hilton': 1,
#               u'Hilton Hotels & Resorts': 1,
#               u'La Quinta Inn and Suites': 1,
#               'NONE': 7,
#               u'Nordic Choice Hotels': 32,
#               u'Nordic Choice Hotels, Clarion Collection': 24,
#               u'Red Roof Inn': 1,
#               u'Residence Inn': 1,
#               u'Sleep Inn': 1}),
#  u'CLASSIC BRITISH': defaultdict(int,
#              {u'Classic British Hotels': 37,
#               u'Classic British Hotels, HRH Group': 2,
#               u'Eden Hotel Collection': 1,
#               'NONE': 6}),
#  u'CLASSIC INTL HOTELS': defaultdict(int,
#              {u'Agenda': 1,
#               u'Artery Hotels': 1,
#               u'Classic Hotels': 2,
#               u'Domus Hotels': 1,
#               u'FOCUS': 5,
#               u'GreenLine Hotels': 2,
#               u'Grupa Hoteli WAM': 12,
#               u'Hotele Logos': 1,
#               u'Hotels Nu\xf1ez y Navarro': 1,
#               u'Hunguest Hotels': 3,
#               u'IBB Hotels': 1,
#               u'Laris Hotels': 1,
#               u'Likus Hotels': 4,
#               u'Logis International': 1,
#               u'Motel One': 1,
#               u'NH Hotels': 1,
#               'NONE': 409,
#               u'Polish Prestige Hotels &amp; Resorts': 8,
#               u'PrivateCityHotels.': 1,
#               u'Santika Indonesia Hotels &amp; Resorts': 1,
#               u'Swiss Budget Hotels': 2,
#               u'Terme Maribor': 3,
#               u'Tulip Inn': 1,
#               u'Ventus Rosa Group': 2,
#               u'Westin': 1,
#               u'easyHotel': 2}),
#  u'CLUB QUARTERS HOTELS': defaultdict(int, {u'Club Quarters': 13}),
#  u'COAST HTLS AND RSTS': defaultdict(int,
#              {u'Coast Hotels &amp; Resorts': 27,
#               'NONE': 2,
#               u'Sandman Hotel Group': 1,
#               u'Super 8': 1,
#               u'Westin': 1}),
#  u'COLUMBUS RESERVATION': defaultdict(int,
#              {u'Countryside Hotels': 1,
#               u'Danske Hoteller': 16,
#               u'Guldsmeden Hotels': 4,
#               u'Meriton Hotels': 1,
#               u'Milling Hotels': 2,
#               'NONE': 35,
#               u'Pestana Hotels &amp; Resorts': 1,
#               u'Petit Hotel': 1,
#               u'Small Danish Hotels': 1,
#               u'Van der Valk Hotels': 1}),
#  u'COMFORT INN': defaultdict(int,
#              {u'AmericInn': 1,
#               u'Best Western': 1,
#               u'Clarion': 2,
#               u'Comfort Inn': 959,
#               u'Comfort Inn, Aimbridge Hospitality': 2,
#               u'Comfort Inn, Atlantica Hotels International': 3,
#               u'Comfort Inn, Continental Hotels': 2,
#               u'Comfort Inn, Nordic Choice Hotels': 10,
#               u'Comfort Inn, Recommended Hotels': 1,
#               u'Comfort Inn, Star Inn Hotels': 7,
#               u'Comfort Inn, Sterling Hotels': 1,
#               u'Comfort Suites': 15,
#               u'Country Inns &amp; Suites': 2,
#               u'Days Inn': 11,
#               u'Econo Lodge': 6,
#               u'Fairfield Inn': 2,
#               u'Hampton by Hilton': 7,
#               u'Hilton Garden Inn': 1,
#               u'Hilton Hotels & Resorts': 1,
#               u'Holiday Inn Express': 7,
#               u'Holiday Inn Hotels & Resorts': 4,
#               u'Howard Johnson': 1,
#               u'Knights Inn': 1,
#               u'La Quinta Inn and Suites': 5,
#               'NONE': 25,
#               u'Nordic Choice Hotels': 19,
#               u'Quality Inn': 8,
#               u'Quality Inn, Star Inn Hotels': 1,
#               u'Residence Inn': 2,
#               u'Rodeway Inn': 1,
#               u'Sleep Inn': 2,
#               u'Super 8': 3,
#               u'Urban Style': 1,
#               u'hotelF1': 3}),
#  u'COMFORT SUITES': defaultdict(int,
#              {u'Baymont Inn &amp; Suites': 3,
#               u'Best Western Plus': 1,
#               u'Comfort Inn': 4,
#               u'Comfort Suites': 394,
#               u'Comfort Suites, Shaner Hotels': 1,
#               u'Comfort Suites, Sterling Hotels': 1,
#               u'Comfort Suites, Vacanc\xe9ole': 1,
#               u'Country Inns &amp; Suites': 5,
#               u'Courtyard by Marriott': 3,
#               u'Days Inn': 4,
#               u'Drury': 2,
#               u'Econo Lodge': 4,
#               u'Fairfield Inn': 2,
#               u'Hampton by Hilton': 3,
#               u'Holiday Inn Express': 1,
#               u'La Quinta Inn and Suites': 3,
#               u'Marriott Hotels & Resorts': 1,
#               u'Microtel Inns &amp; Suites': 1,
#               u'Motel6': 5,
#               'NONE': 6,
#               u'Sandman Hotel Group': 1,
#               u'Sleep Inn': 1,
#               u'Super 8': 3}),
#  u'COMO HOTELS & RSTS': defaultdict(int, {u'COMO': 3, 'NONE': 1}),
#  u'CONRAD': defaultdict(int,
#              {u'Conrad Hotels &amp; Resorts': 14,
#               u'Hilton Hotels & Resorts': 2,
#               'NONE': 1}),
#  u'CORINTHIA HOTELS': defaultdict(int, {u'Corinthia Hotels': 7, 'NONE': 1}),
#  u'COUNTRY INN SUITES': defaultdict(int,
#              {u'Baymont Inn &amp; Suites': 1,
#               u'Country Inns &amp; Suites': 351,
#               u'Country Inns &amp; Suites, GF Hotels': 2,
#               u'Days Inn': 3,
#               u'Drury': 5,
#               u'Econo Lodge': 3,
#               u'Fairfield Inn': 2,
#               u'Hampton by Hilton': 2,
#               u'Holiday Inn Express': 6,
#               u'Holiday Inn Hotels & Resorts': 2,
#               u'La Quinta Inn and Suites': 15,
#               u'Motel6': 1,
#               'NONE': 5,
#               u'Quality Inn': 6,
#               u'Residence Inn': 2,
#               u'Rodeway Inn': 1,
#               u'Super 8': 1}),
#  u'COURTYARD HOTELS': defaultdict(int,
#              {u'Comfort Inn': 1,
#               u'Courtyard by Marriott': 783,
#               u'Hilton Garden Inn': 1,
#               u'Holiday Inn Express': 1,
#               u'JW Marriott Hotels & Resorts': 1,
#               u'Jurys Inns': 1,
#               u'Marriott Hotels & Resorts': 7,
#               'NONE': 7,
#               u'Ramada': 1}),
#  u'CROWNE PLAZA HOTELS': defaultdict(int,
#              {u'Crowne Plaza Hotels &amp; Resorts': 291,
#               u'Crowne Plaza Hotels &amp; Resorts, Aimbridge Hospitality': 1,
#               u'Crowne Plaza Hotels &amp; Resorts, Apollo Hotels &amp; Resorts': 1,
#               u'Crowne Plaza Hotels &amp; Resorts, Atrium Hotels': 1,
#               u'Crowne Plaza Hotels &amp; Resorts, Classic British Hotels': 1,
#               u'Crowne Plaza Hotels &amp; Resorts, Crestline Hotels': 1,
#               u'Crowne Plaza Hotels &amp; Resorts, Legacy Hotels': 1,
#               u'Fattal Hotels': 1,
#               u'Holiday Inn Express': 1,
#               u'Home Inn': 1,
#               'NONE': 8}),
#  u'CURIO COLLECTION': defaultdict(int,
#              {u'Curio Collection by Hilton': 21,
#               u'Curio Collection by Hilton, Destination hotels': 1,
#               u'Doubletree by Hilton': 2}),
#  u'DAYS INN': defaultdict(int,
#              {u'Americas Best Value Inn, Red Lion Hotels': 1,
#               u'Baymont Inn &amp; Suites': 3,
#               u'Best Western': 1,
#               u'Budget Host Hotels': 1,
#               u'Coast Hotels &amp; Resorts': 1,
#               u'Comfort Inn': 3,
#               u'Comfort Suites': 1,
#               u'Country Inns &amp; Suites': 3,
#               u'Days Inn': 1096,
#               u'Days Inn, Roadchef': 11,
#               u'Days Inn, Station Casino': 1,
#               u'Days Inn, Welcome Break': 13,
#               u'Doubletree by Hilton': 1,
#               u'Drury': 4,
#               u'Econo Lodge': 5,
#               u'Fairfield Inn': 5,
#               u'Hampton by Hilton': 15,
#               u'Hilton Garden Inn': 2,
#               u'Holiday Inn Express': 35,
#               u'Holiday Inn Hotels & Resorts': 14,
#               u'Hostelling International': 1,
#               u'Hostelling International USA': 1,
#               u'Howard Johnson': 4,
#               u'Knights Inn': 5,
#               u'La Quinta Inn and Suites': 12,
#               u'Le Meridien Hotels &amp; Resorts': 1,
#               u'Motel6': 6,
#               'NONE': 38,
#               u'Quality Inn': 25,
#               u'Ramada': 1,
#               u'Red Lion Hotels, GuestHouse': 2,
#               u'Red Roof Inn': 5,
#               u'Residence Inn': 5,
#               u'Rodeway Inn': 8,
#               u'Sleep Inn': 2,
#               u'Staybridge Suites': 1,
#               u'Sterling Hotels': 1,
#               u'Super 8': 12,
#               u'Travelodge by Wyndham': 1,
#               u'Tryp': 1,
#               u'Vagabond Inn': 1,
#               u'Wyndham Hotels &amp; Resorts': 1,
#               u'Wyndham Hotels &amp; Resorts, Americas Best Value Inn, Red Lion Hotels': 1,
#               u'[Plateno Hotels Group] 7Days Inn': 4}),
#  u'DELTA HOTELS': defaultdict(int,
#              {u'Delta': 20,
#               u'Fairmont Hotels &amp; Resorts': 1,
#               u'Hilton Hotels & Resorts': 3,
#               u'Holiday Inn Hotels & Resorts': 1,
#               u'Marriott Hotels & Resorts': 1,
#               'NONE': 3,
#               u'Ramada': 1,
#               u'Travelodge by Wyndham': 1,
#               u'W Hotels': 1}),
#  u'DENIHAN HOSPITALITY': defaultdict(int, {'NONE': 7}),
#  u'DESIGN HOTELS': defaultdict(int,
#              {u'Alila hotels': 5,
#               u'Altis Hotels': 1,
#               u'Chandris Hotels &amp; Resorts': 1,
#               u'Derby Hotels': 2,
#               u'Design Hotels': 51,
#               u'Design Hotels, Grupo Habita': 1,
#               u'Design Hotels, K\xe4mp Collection Hotels': 1,
#               u'Design Hotels, Nordic Choice Hotels': 1,
#               u'Design Hotels, Thanos Hotels': 1,
#               u'Europe Hotels': 1,
#               u'Grupo Habita': 2,
#               u'Hospes': 2,
#               u'Inntel, Design Hotels': 1,
#               u'Maistra d.d.': 1,
#               'NONE': 123,
#               u'Nordic Choice Hotels': 1,
#               u'Novum Hotels': 1,
#               u'Ovolo Group': 1,
#               u'Playa Senator': 1,
#               u'The House Hotels': 1,
#               u'The Park Hotels': 6}),
#  u'DESTINATION HOTELS': defaultdict(int,
#              {u'Destination hotels': 28, 'NONE': 5}),
#  u'DIVAN HOTELS': defaultdict(int, {u'Divan Hotels': 9, 'NONE': 4}),
#  u'DOLCE HTLS & RESORTS': defaultdict(int,
#              {u'Crown Vacation Rentals': 1,
#               u'Dolce Hotels &amp; Resorts': 10}),
#  u'DORCHESTERCOLLECTION': defaultdict(int,
#              {u'Dorchester Collection': 6, 'NONE': 1}),
#  u'DORINT HTL & RESORTS': defaultdict(int, {u'Dorint Hotels': 30, 'NONE': 2}),
#  u'DOUBLETREE HOTELS': defaultdict(int,
#              {u'Days Inn': 1,
#               u'Doubletree by Hilton': 253,
#               u'Doubletree by Hilton, Aimbridge Hospitality': 10,
#               u'Doubletree by Hilton, GF Hotels': 4,
#               u'Drury': 1,
#               u'Even Hotels &amp; Resorts': 1,
#               u'Hampton by Hilton': 1,
#               u'Hilton Garden Inn': 1,
#               u'Hilton Hotels & Resorts': 7,
#               u'Holiday Inn Express': 1,
#               u'Homewood Suites by Hilton': 1,
#               u'Hotel Indigo': 1,
#               u'La Quinta Inn and Suites': 1,
#               u'Motel6': 1,
#               'NONE': 3,
#               u'Portfolio Hotels, Doubletree by Hilton': 1,
#               u'Quality Inn': 1,
#               u'Red Roof Inn': 1,
#               u'Residence Inn': 1,
#               u'Sonesta Collection Hotels': 1,
#               u'Wyndham Hotels &amp; Resorts': 1}),
#  u'DREAM HOTELS': defaultdict(int, {u'Dream Hotel Group': 6, 'NONE': 1}),
#  u'DRURY INN': defaultdict(int,
#              {u'Country Inns &amp; Suites': 1,
#               u'Drury': 91,
#               u'Fairfield Inn': 1,
#               u'Hampton by Hilton': 1,
#               u'Holiday Inn Express': 3,
#               u'Holiday Inn Hotels & Resorts': 1,
#               u'Home2 Suites by Hilton': 1,
#               'NONE': 4,
#               u'Quality Inn': 2,
#               u'Red Roof Inn': 2,
#               u'Super 8': 2}),
#  u'DUSIT HTLS & RESORTS': defaultdict(int,
#              {u'Dusit Hotels &amp; Resorts': 13, 'NONE': 1}),
#  u'EATON HOTELS': defaultdict(int, {u'Langham Hotels International': 3}),
#  u'ECONOLODGE': defaultdict(int,
#              {u'Aloft': 1,
#               u'Best Western': 3,
#               u'Comfort Inn': 2,
#               u'Comfort Suites': 2,
#               u'Days Inn': 2,
#               u'Econo Lodge': 557,
#               u'Econo Lodge, Americas Best Inn': 2,
#               u'Econo Lodge, Sterling Hotels': 1,
#               u'Hampton by Hilton': 5,
#               u'Hilton Hotels & Resorts': 2,
#               u'Holiday Inn Express': 7,
#               u'Homewood Suites by Hilton': 1,
#               u'Howard Johnson': 4,
#               u'Knights Inn': 2,
#               u'La Quinta Inn and Suites': 1,
#               u'Motel6': 12,
#               'NONE': 24,
#               u'Quality Inn': 7,
#               u'Ramada': 3,
#               u'Red Carpet Inn &amp; Suites': 1,
#               u'Red Lion Hotels, Country Hearth Inn &amp; Suites': 1,
#               u'Red Lion Hotels, GuestHouse': 2,
#               u'Red Roof Inn': 3,
#               u'Super 8': 12,
#               u'Travelodge by Wyndham': 1,
#               u'Wyndham Hotels &amp; Resorts': 1}),
#  u'EDITION BRAND': defaultdict(int, {u'Edition': 2, 'NONE': 1}),
#  u'ELEMENT HOTELS': defaultdict(int, {u'Westin': 1}),
#  u'EMBASSY SUITES': defaultdict(int,
#              {u'Drury': 1,
#               u'Embassy Suites Hotels': 177,
#               u'Hilton Garden Inn': 1,
#               u'Holiday Inn Express': 1,
#               u'La Quinta Inn and Suites': 1,
#               'NONE': 1,
#               u'Renaissance Hotels &amp; Resorts': 1,
#               u'Residence Inn': 2,
#               u'Staybridge Suites': 1,
#               u'TownePlace Suites by Marriott': 1}),
#  u'EPOQUE HOTELS': defaultdict(int,
#              {u'Guadalpin Hoteles': 1,
#               u'Les H\xf4tels de Paris': 1,
#               'NONE': 36,
#               u'Una Hotels &amp; Resorts': 1,
#               u'Westin': 1}),
#  u'EVEN HOTELS': defaultdict(int,
#              {u'Element by Westin': 1,
#               u'Even Hotels &amp; Resorts': 4,
#               'NONE': 1}),
#  u'EXTENDED STAY': defaultdict(int, {u'Extended Stay America': 523}),
#  u'FAIRFIELD INN HOTELS': defaultdict(int,
#              {u'Fairfield Inn': 633,
#               u'Fairfield Inn, Aimbridge Hospitality': 2,
#               u'Fairfield Inn, Crestline Hotels': 2,
#               u'Fairfield Inn, GF Hotels': 2,
#               u'Fairfield Inn, Shaner Hotels': 9,
#               u'Holiday Inn Express': 1,
#               u'Marriott Hotels & Resorts': 2,
#               u'Microtel Inns &amp; Suites': 1,
#               'NONE': 3,
#               u'Wyndham Hotels &amp; Resorts': 1}),
#  u'FAIRMONT HOTELS': defaultdict(int,
#              {u'Fairmont Hotels &amp; Resorts': 44,
#               'NONE': 4,
#               u'Radisson': 1,
#               u'Ramada': 1,
#               u'The Leading Hotels of the World, Swiss Deluxe Hotels, Fairmont Hotels &amp; Resorts': 1}),
#  u'FASTBOOKING': defaultdict(int,
#              {u'Adriatic Luxury Hotels': 4,
#               u"Appart'City": 1,
#               u'B&amp;B Hotels': 3,
#               u'Barriere': 6,
#               u'Blue Sea Hotels &amp; Resorts': 1,
#               u'Charme e Relax': 2,
#               u'Chateaux et Hotels Collection': 1,
#               u'Club Mahindra': 1,
#               u'Domina Hotel Group': 1,
#               u'Elan': 1,
#               u'Golden Tulip': 1,
#               u'Guldsmeden Hotels': 1,
#               u'Hotel Monterey Group': 15,
#               u'Hoteles Globales': 5,
#               u'Hoteles Silken': 1,
#               u'IBB Hotels': 2,
#               u'Interhome': 2,
#               u'Ishin Hotels Group': 1,
#               u'Logis International': 3,
#               u'Luna Hoteis': 2,
#               u'MH Apartments': 1,
#               u'Madame Vacances': 1,
#               u'Mercure': 3,
#               u'Mokinba  Hotels': 4,
#               'NONE': 582,
#               u'Newhotel': 2,
#               u'Oceania': 1,
#               u'Pickalbatros': 5,
#               u'Prestige': 1,
#               u'ReMar Hotels': 2,
#               u'Resta Hotels &amp; Resorts': 1,
#               u'Sall\xe9s Hotels': 3,
#               u'Small Luxury Hotels of the World': 1,
#               u'Staycity Aparthotels': 1,
#               u'Travelopo': 1,
#               u'Urlaub am Bauernhof': 1,
#               u'Vacances Bleues': 2,
#               u'Vacanc\xe9ole': 2}),
#  u'FIESTA AMERICANA': defaultdict(int,
#              {u'Camino Real': 1,
#               u'Grupo Posadas': 69,
#               u'Grupo Posadas, One Hotels': 21,
#               u'Holiday Inn Hotels & Resorts': 3,
#               'NONE': 7,
#               u'Ostar': 1,
#               u'Quality Inn': 1,
#               u'Sleep Inn': 1,
#               u'ibis': 2}),
#  u'FIRST HOTELS': defaultdict(int,
#              {u'First Hotels': 48,
#               u'First Hotels, Design Hotels': 1,
#               u'First Hotels, Your Hotel': 1,
#               'NONE': 2,
#               u'Petit Palace Hoteles': 23,
#               u'Svenska Turistf\xf6reningen, Hostelling International': 1}),
#  u'FOUR SEASONS HOTELS': defaultdict(int,
#              {u'Four Seasons Hotels and Resorts': 62,
#               'NONE': 5,
#               u'Ramada': 1,
#               u'St. Regis': 1}),
#  u'FRASERS HOSPITALITY': defaultdict(int,
#              {u'Capri by Fraser': 2,
#               u'Fraser Place': 7,
#               u'Fraser Residence': 7,
#               u'Fraser Suites': 13,
#               u'Modena by Fraser': 3,
#               'NONE': 4,
#               u'Renaissance Hotels &amp; Resorts': 1,
#               u'SB Hotels': 1}),
#  u'GAMMA HOTELS': defaultdict(int, {u'Club Quarters': 1, u'Grupo Posadas': 7}),
#  u'GANSEVOORT HOTEL GRP': defaultdict(int, {'NONE': 3}),
#  u'GAYLORD ENTERTAINMEN': defaultdict(int, {u'Gaylord Hotels': 4}),
#  u'GENARES WORLDWIDE': defaultdict(int,
#              {u'Hampton by Hilton': 1,
#               u'Hostelling International USA': 1,
#               'NONE': 72,
#               u'Residence Inn': 1,
#               u'Super 8': 1,
#               u'Westin': 1}),
#  u'GENRE HOTELS': defaultdict(int,
#              {'NONE': 11, u'Sixty Hotels': 1, u'Westin': 1}),
#  u'GLOBAL HOSPITALITY': defaultdict(int, {u'Grange hotels': 2}),
#  u'GLOBALHOTEL ALLIANCE': defaultdict(int,
#              {u'Anantara Hotels &amp; Resorts': 17,
#               u'Atlantis Resorts, Emirates whitelabel preferred properties': 1,
#               u'Avani Hotels &amp; Resorts': 2,
#               'NONE': 10}),
#  u'GOLDEN TULIP': defaultdict(int,
#              {u'BHG': 1,
#               u'BHG, Golden Tulip': 3,
#               u'BHG, Tulip Inn': 3,
#               u'Daguisa': 2,
#               u'Element by Westin': 1,
#               u'Golden Tulip': 84,
#               u'Hilton Hotels & Resorts': 1,
#               u'M\xf6venpick Hotels &amp; Resorts': 1,
#               'NONE': 30,
#               u'Nordic Hotels (Germany)': 4,
#               u'Nordic Hotels (Germany), Golden Tulip': 1,
#               u'Oceania': 1,
#               u'Premiere Classe': 1,
#               u'Quality Inn, Atlantica Hotels International': 1,
#               u'Royal Tulip Luxury Hotels': 4,
#               u'The Park Hotels': 1,
#               u'Tulip Inn': 30}),
#  u'GRAND HERITAGE': defaultdict(int, {'NONE': 1}),
#  u'GRAND LIFE HOTELS': defaultdict(int, {'NONE': 2}),
#  u'GRANDSTAYHOSPITALITY': defaultdict(int, {'NONE': 13}),
#  u'GREAT HOTELS': defaultdict(int,
#              {u'Altis Hotels': 2,
#               u'Chateaux et Hotels Collection, Great Hotels of the World': 1,
#               u'Classic Hotels, Small Danish Hotels': 2,
#               u'Danhostel': 1,
#               u'Dolan Hotels': 2,
#               u'Dom Pedro': 5,
#               u'Emirates whitelabel preferred properties': 1,
#               u'Exclusive Hotels': 1,
#               u'Fletcher Hotels': 62,
#               u'Holiday Inn Hotels & Resorts': 1,
#               u'Hotels Nu\xf1ez y Navarro': 1,
#               'NONE': 83,
#               u'Premier Hotels &amp; Resorts': 1,
#               u'Romantik, Charme e Relax': 1,
#               u'Schick Hotels': 3,
#               u'Schick Hotels, PrivateCityHotels.': 2,
#               u'Small Danish Hotels': 41,
#               u'Small Danish Hotels, Montra Hotels': 4,
#               u'Socal Beach Vacations': 1,
#               u'Sol og Strand': 1,
#               u'The Pride Hotels': 5,
#               u'Van der Valk Hotels': 18}),
#  u'HAMPSHIRE HOTELS': defaultdict(int, {u'Hampshire Hotels': 44, 'NONE': 5}),
#  u'HAMPTON INNS': defaultdict(int,
#              {u'Aloft': 1,
#               u'Americas Best Value Inn, Red Lion Hotels': 1,
#               u'Baymont Inn &amp; Suites': 5,
#               u'Best Western': 2,
#               u'Candlewood Suites': 1,
#               u'City Express Hotels': 1,
#               u'Clarion': 1,
#               u'Comfort Inn': 4,
#               u'Comfort Suites': 2,
#               u'Courtyard by Marriott': 1,
#               u'Crowne Plaza Hotels &amp; Resorts': 1,
#               u'Dann Hotels': 1,
#               u'Days Inn': 4,
#               u'Fairfield Inn': 4,
#               u'Hampton by Hilton': 1518,
#               u'Hampton by Hilton, Aimbridge Hospitality': 1,
#               u'Hampton by Hilton, Focus Hotel Group': 2,
#               u'Hampton by Hilton, GF Hotels': 1,
#               u'Hampton by Hilton, John Q Hammons': 2,
#               u'Hampton by Hilton, Shaner Hotels': 1,
#               u'Hilton Garden Inn': 12,
#               u'Hilton Hotels & Resorts': 23,
#               u'Holiday Inn Express': 28,
#               u'Holiday Inn Hotels & Resorts': 10,
#               u'Home2 Suites by Hilton': 1,
#               u'Homewood Suites by Hilton': 2,
#               u'Howard Johnson': 1,
#               u'Hyatt': 1,
#               u'Hyatt Place': 2,
#               u'Hyatt Regency': 1,
#               u'Hyatt house': 2,
#               u'Hyatt, Aimbridge Hospitality': 1,
#               u'Knights Inn': 4,
#               u'La Quinta Inn and Suites': 14,
#               u'Mama Shelter': 1,
#               u'Microtel Inns &amp; Suites': 3,
#               'NONE': 19,
#               u'Quality Inn': 16,
#               u'Ramada': 2,
#               u'Red Carpet Inn &amp; Suites': 2,
#               u'Red Roof Inn': 1,
#               u'Residence Inn': 6,
#               u'Sheraton': 1,
#               u'Sleep Inn': 1,
#               u'Staybridge Suites': 1,
#               u'TownePlace Suites by Marriott': 1,
#               u'Travelodge by Wyndham': 1}),
#  u'HARRAHS HOTELS': defaultdict(int,
#              {u'Caesars Entertainment': 19,
#               u'Caesars Entertainment, Caesar Hotels': 2}),
#  u'HAWTHORN SUITES': defaultdict(int,
#              {u'AmericInn': 1,
#               u'Comfort Suites': 1,
#               u'Country Inns &amp; Suites': 1,
#               u'Hampton by Hilton': 2,
#               u'Hawthorn Suites': 75,
#               u'Hilton Hotels & Resorts': 1,
#               'NONE': 1,
#               u'Westin': 1,
#               u'Wyndham Hotels &amp; Resorts': 2}),
#  u'HELIX HOTELS': defaultdict(int, {'NONE': 2}),
#  u'HETRAS RESERVATIONS': defaultdict(int, {'NONE': 14}),
#  u'HILTON GARDEN INNS': defaultdict(int,
#              {u'Camino Real': 1,
#               u'Hampton by Hilton': 4,
#               u'Hawthorn Suites': 1,
#               u'Hilton Garden Inn': 514,
#               u'Hilton Hotels & Resorts': 1,
#               u'Holiday Inn Express': 1,
#               u'Holiday Inn Hotels & Resorts': 1,
#               u'Hyatt house': 1,
#               u'M\xf6venpick Hotels &amp; Resorts': 1,
#               'NONE': 3,
#               u'Quality Inn': 1,
#               u'Radisson': 1,
#               u'Red Lion Hotels, GuestHouse': 1,
#               u'Red Roof Inn': 1,
#               u'Renaissance Hotels &amp; Resorts, John Q Hammons': 1,
#               u'Residence Inn': 4,
#               u'Residence Inn, Crestline Hotels': 1,
#               u'Residence Inn, John Q Hammons': 1,
#               u'Rodeway Inn': 1,
#               u'SACO Apartments': 1,
#               u'Sheraton': 1,
#               u'Sleep Inn': 1,
#               u'Sofitel': 1,
#               u'Travelodge by Wyndham': 1,
#               u'Wyndham Hotels &amp; Resorts': 1}),
#  u'HILTON HOTELS': defaultdict(int,
#              {u'Cairn Hotels': 1,
#               u'Doubletree by Hilton': 79,
#               u'Doubletree by Hilton, Focus Hotel Group': 1,
#               u'Hampton by Hilton': 1,
#               u'Hilton Hotels & Resorts': 152,
#               u'Hyatt Regency': 1,
#               u'InterContinental Hotels &amp; Resorts': 1,
#               u'Marriott Hotels & Resorts': 1,
#               'NONE': 22,
#               u'Novotel': 1,
#               u'Radisson Blu': 1,
#               u'Sheraton': 1,
#               u'The Ritz-Carlton Company, L.L.C': 1,
#               u'Vienna Hotel': 1,
#               u'Wyndham Hotels &amp; Resorts': 1,
#               u'ibis': 1}),
#  u'HILTON HOTELS CORPO': defaultdict(int,
#              {u'AM Resorts': 1,
#               u'Aloft': 1,
#               u'Best Western Plus': 1,
#               u'Comfort Inn': 1,
#               u'Courtyard by Marriott': 1,
#               u'Doubletree by Hilton': 1,
#               u'Embassy Suites Hotels': 1,
#               u'Hilton Garden Inn': 4,
#               u'Hilton Grand Vacations': 14,
#               u'Hilton Hotels & Resorts': 192,
#               u'Holiday Inn Express': 3,
#               u'Holiday Inn Hotels & Resorts': 1,
#               u'Homewood Suites by Hilton': 2,
#               u'Hostelling International USA': 1,
#               u'Marriott Hotels & Resorts': 1,
#               u'Morgans Hotel Group': 1,
#               u'Motel6': 1,
#               'NONE': 11,
#               u'Quality Inn': 1,
#               u'Red Lion Hotels': 1,
#               u'Residence Inn': 2,
#               u'Sheraton': 2,
#               u'The Ritz-Carlton Company, L.L.C': 1,
#               u'W Hotels': 1,
#               u'Westin': 1,
#               u'Wyndham Garden': 1}),
#  u'HISTORIC HOTELS': defaultdict(int,
#              {u'Historic Hotels of America': 1, 'NONE': 28}),
#  u'HOLIDAY INN': defaultdict(int,
#              {u'Americas Best Value Inn, Red Lion Hotels': 1,
#               u'Baymont Inn &amp; Suites': 3,
#               u'Comfort Inn': 2,
#               u'Comfort Suites': 1,
#               u'Country Inns &amp; Suites': 2,
#               u'Days Inn': 22,
#               u'Delta': 1,
#               u'Drury': 2,
#               u'Econo Lodge': 1,
#               u'Fairfield Inn': 1,
#               u'Four Points by Sheraton': 1,
#               u'Hampton by Hilton': 15,
#               u'Hampton by Hilton, Shaner Hotels': 1,
#               u'Hilton Garden Inn': 3,
#               u'Hilton Hotels & Resorts': 3,
#               u'Holiday Inn Express': 1753,
#               u'Holiday Inn Hotels & Resorts': 829,
#               u'Howard Johnson': 2,
#               u'InterContinental Hotels &amp; Resorts': 2,
#               u'Jurys Inns': 1,
#               u'Knights Inn': 1,
#               u'La Quinta Inn and Suites': 19,
#               u'Marlin Apartments': 1,
#               u'Marriott Hotels & Resorts': 1,
#               u'Microtel Inns &amp; Suites': 1,
#               'NONE': 49,
#               u'Newhotel': 1,
#               u'Quality Inn': 31,
#               u'Ramada': 1,
#               u'Red Carpet Inn &amp; Suites': 1,
#               u'Red Roof Inn': 3,
#               u'Residence Inn': 1,
#               u'Rodeway Inn': 5,
#               u'Sleep Inn': 6,
#               u'Super 8': 1,
#               u'Travelodge by Wyndham': 1,
#               u'[Plateno Hotels Group] 7Days Inn': 2,
#               u'ibis': 2}),
#  u'HOME2 SUITES': defaultdict(int,
#              {u'Best Western': 1,
#               u'Comfort Inn': 3,
#               u'Comfort Suites': 1,
#               u'Doubletree by Hilton': 1,
#               u'Econo Lodge': 1,
#               u'Hampton by Hilton': 8,
#               u'Hilton Hotels & Resorts': 9,
#               u'Holiday Inn Express': 1,
#               u'Holiday Inn Hotels & Resorts': 1,
#               u'Home2 Suites by Hilton': 75,
#               u'Homewood Suites by Hilton': 7,
#               u'Knights Inn': 1,
#               u'Motel6, Aimbridge Hospitality': 1,
#               u'Residence Inn': 1,
#               u'Super 8': 3,
#               u'TownePlace Suites by Marriott': 2,
#               u'Westin': 1}),
#  u'HOMEWOOD SUITES': defaultdict(int,
#              {u'Best Western': 2,
#               u'Candlewood Suites': 1,
#               u'Comfort Inn': 2,
#               u'Comfort Suites': 1,
#               u'Courtyard by Marriott': 1,
#               u'Days Inn': 4,
#               u'Doubletree by Hilton': 1,
#               u'Embassy Suites Hotels': 3,
#               u'Hampton by Hilton': 6,
#               u'Hawthorn Suites': 1,
#               u'Hilton Garden Inn': 1,
#               u'Hilton Hotels & Resorts': 5,
#               u'Holiday Inn Express': 2,
#               u'Holiday Inn Hotels & Resorts': 2,
#               u'Home2 Suites by Hilton': 1,
#               u'Homewood Suites by Hilton': 295,
#               u'Hotel Indigo': 1,
#               u'Hyatt Place': 2,
#               u'Hyatt house': 2,
#               u'La Quinta Inn and Suites': 1,
#               u'Marriott Hotels & Resorts': 1,
#               u'Motel6': 1,
#               'NONE': 4,
#               u'Ramada': 2,
#               u'Red Lion Hotels, GuestHouse': 1,
#               u'SpringHill Suites': 2,
#               u'Wyndham Hotels &amp; Resorts': 1}),
#  u'HOTEL INDIGO': defaultdict(int,
#              {u'Hotel Indigo': 56,
#               u'InterContinental Hotels &amp; Resorts, Hotel Indigo': 1,
#               'NONE': 7,
#               u'Sleep Inn': 1}),
#  u'HOTELREZ HTLS & RSTS': defaultdict(int,
#              {u'AS Hotels': 4,
#               u'Americas Best Value Inn, Red Lion Hotels': 1,
#               u'BCN City Hotels': 1,
#               u'Barcelona Apartment': 2,
#               u'Classic British Hotels': 1,
# ...
#              {'NONE': 3, u'Taj Hotels, Resorts and Palaces': 47}),
#  u'TFE HOTELS': defaultdict(int,
#              {u'Adina': 5,
#               'NONE': 1,
#               u'Park Plaza Hotels &amp; Resorts': 1,
#               u'Ramada': 1,
#               u'Worldhotels': 1}),
#  u'THE ADDRESS': defaultdict(int,
#              {u'The Address Hotels and Resorts': 3,
#               u'The Address Hotels and Resorts, Emirates whitelabel preferred properties': 1,
#               u'Vida Hotels and Resorts': 1,
#               u'Vida Hotels and Resorts, Emirates whitelabel preferred properties': 1}),
#  u'THE DOYLE COLLECTION': defaultdict(int, {'NONE': 3}),
#  u'THE LALIT': defaultdict(int, {u'The LaLiT Suri Hospitality Group': 7}),
#  u'THE PENINSULA HOTELS': defaultdict(int,
#              {'NONE': 1,
#               u'Novotel': 1,
#               u'The Peninsula Hotels': 2,
#               u'Trump Hotel Collection': 1}),
#  u'THISTLE HOTELS': defaultdict(int, {'NONE': 1, u'Thistle': 2}),
#  u'THOMPSON HOTELS': defaultdict(int,
#              {'NONE': 1,
#               u'The Ritz-Carlton Company, L.L.C': 1,
#               u'Thompson hotels': 5}),
#  u'THON HOTELS': defaultdict(int,
#              {u'NH Hotels': 1,
#               'NONE': 2,
#               u'Thon Hotels': 14,
#               u'Thon Hotels, Thon Budget': 5,
#               u'Thon Hotels, Thon City': 24,
#               u'Thon Hotels, Thon Conference': 19}),
#  u'TOP INTL HOTELS': defaultdict(int,
#              {u'Centro Hotel Group': 1,
#               u'Europe Hotels': 1,
#               u'Fosshotel': 1,
#               u'G\xfcnnewig Hotels': 4,
#               u'G\xfcnnewig Hotels, Centro Hotel Group': 1,
#               'NONE': 34,
#               u'TOP Hotels': 9,
#               u'TOP Hotels, City Partner': 1,
#               u'TOP Hotels, Europe Hotels': 1,
#               u'TOP Hotels, VCH Hotels': 2,
#               u'Top City &amp; CountryLine Hotels': 5,
#               u'VCH Hotels': 8}),
#  u'TOWNEPLACE SUITES': defaultdict(int,
#              {u'Marriott Hotels & Resorts': 2,
#               'NONE': 2,
#               u'TownePlace Suites by Marriott': 218}),
#  u'TRAVEL TRIPPER': defaultdict(int,
#              {u'Baymont Inn &amp; Suites': 1,
#               u'Ctwo Hotels': 2,
#               u'Global Serviced Apts': 8,
#               u'Greystone Hospitality': 1,
#               u'Loews Hotels': 2,
#               u'Marriott Hotels & Resorts': 1,
#               'NONE': 142}),
#  u'TRAVELCLICK': defaultdict(int,
#              {u'AM Resorts': 1,
#               u'AMERON Hotel Collection': 3,
#               u'APA Hotels&Resorts': 1,
#               u'Adagio Aparthotels': 1,
#               u'Adrian Hoteles': 1,
#               u'Adriatic Luxury Hotels': 1,
#               u'Aimbridge Hospitality': 1,
#               u'Aitken Spence Hotels': 4,
#               u'Althoff Hotel Collection': 1,
#               u'Amrath Hotels': 6,
#               u'Anemon Hotels': 11,
#               u'Anima Hotels': 1,
#               u'Apollo Hotels &amp; Resorts': 7,
#               u'Ascend Collection': 1,
#               u'Ascott The Residence': 1,
#               u'Asten Hotels': 3,
#               u'Aston International Hotels, Resorts &amp; Residences': 2,
#               u'Atton': 1,
#               u'Austria Hotels International': 4,
#               u'Austria Trend Hotels': 18,
#               u'Ayres Hotels': 15,
#               u'Azimut': 17,
#               u'Baglioni Hotels': 1,
#               u'Bah\xeda Pr\xedncipe Hotels &amp; Resorts': 2,
#               u'Best Western': 1,
#               u'Boudl Hotels &amp; Hotel Suites': 1,
#               u'Britannia Hotels': 28,
#               u'Cairn Hotels': 5,
#               u'Carr\xeds Hoteles': 2,
#               u'Castle Resorts &amp; Hotels': 15,
#               u'Charme e Relax': 3,
#               u'Chateaux et Hotels Collection': 1,
#               u'Citrus Hotels': 6,
#               u'Classic British Hotels': 2,
#               u'Classic Lodges': 3,
#               u'Comfort Inn': 3,
#               u'Compass Hospitality': 2,
#               u'Comwell Hotels': 16,
#               u'Countryside Hotels': 1,
#               u'Crestline Hotels': 2,
#               u'Danubius Hotels': 1,
#               u'Days Inn': 1,
#               u'Design Hotels': 1,
#               u'Divani Collection': 1,
#               u'Divi Resorts': 3,
#               u'Drury': 1,
#               u'EA Hotels': 4,
#               u'Eastin Hotels &amp; Residences': 7,
#               u'Emporio Hotels &amp; Resorts': 2,
#               u'Epoque Hotels': 1,
#               u'Europa Group': 6,
#               u'Floris Hotels': 2,
#               u'GF Hotels': 2,
#               u'GRT Hotels and Resorts': 1,
#               u'Geisel Privathotels': 1,
#               u'Green Park Hotels': 1,
#               u'Groupe BOAS': 9,
#               u'Groupe Germain': 9,
#               u'Grupo Regina Hoteles': 3,
#               u'H-Hotels.com': 2,
#               u'H10 Hotels': 5,
#               u'Hampton by Hilton': 1,
#               u'Hanting Inns & Hotels': 1,
#               u'Harbour Plaza Hotels &amp; Resorts': 1,
#               u'Harmony Resorts': 1,
#               u'Hilton Hotels & Resorts': 2,
#               u'Historic Hotels': 2,
#               u'Historic Hotels of America': 2,
#               u'Holiday Inn Express': 1,
#               u'Holiday Inn Hotels & Resorts': 1,
#               u'Hoposa': 8,
#               u'Hoseasons': 1,
#               u'Hospes': 1,
#               u'Hostelling International, Hostelling International USA': 1,
#               u'Hoteis Seara LTDA': 3,
#               u'Hotel Indigo': 1,
#               u'Hotele Diament': 9,
#               u'Hoteles Andaluces con Encanto': 5,
#               u'Hoteles Estelar': 3,
#               u'Hotels Nu\xf1ez y Navarro': 1,
#               u'Howard Johnson': 1,
#               u'Hyatt': 1,
#               u'H\xb7Top Hotels Group': 7,
#               u'H\xf4tels Gouverneur': 7,
#               u'Imperial': 3,
#               u'Innotality': 4,
#               u'Interhome': 2,
#               u'Isrotel Hotels &amp; Resorts': 1,
#               u'JI Hotels': 1,
#               u'JJW Hotels &amp; Resorts': 4,
#               u'John Q Hammons': 3,
#               u'K+K Hotels': 1,
#               u'Kenzi': 6,
#               u'Knights Inn': 1,
#               u'LDC Group': 5,
#               u'Lakeview Hotels &amp; Resorts': 19,
#               u'Legacy Hotels': 4,
#               u'Libertador': 1,
#               u'Macdonald Hotels &amp; Resorts': 1,
#               u'Maldron': 1,
#               u'Malmaison': 1,
#               u'Marriott Hotels & Resorts': 1,
#               u'Muthu Group': 1,
#               u'M\xf6venpick Hotels &amp; Resorts': 1,
#               'NONE': 2480,
#               u'National 9 Inn': 1,
#               u'Nova Hotels': 4,
#               u'Novina Hotels': 2,
#               u'Oasis Hotels &amp; Resorts': 1,
#               u'Oberoi Hotels &amp; Resorts': 1,
#               u'Omni Hotels': 1,
#               u'Outrigger Hotels Hawaii': 1,
#               u'POP! Hotels': 1,
#               u'Palace Resorts': 5,
#               u'Palladium Hotel Group': 4,
#               u'Pan Pacific Hotels &amp; Resorts': 1,
#               u'Park Hyatt': 1,
#               u'Park Royal Hotels &amp; Resorts': 4,
#               u'Planetaria Hotels': 3,
#               u'Porto Bay Hotels &amp; Resorts': 6,
#               u'Premier Apartments': 4,
#               u'Prestige': 1,
#               u'Qubus Hotel': 11,
#               u'Radisson Blu': 1,
#               u'Rafaelhoteles': 4,
#               u'Real Resorts': 1,
#               u'Recommended Hotels': 1,
#               u'Red Roof Inn': 1,
#               u'Relais &amp; Ch\xe2teaux': 2,
#               u'Retaj Hotels &amp; Hospitality': 3,
#               u'Rivoli Hotels': 2,
#               u'Rixos Hotels': 15,
#               u'Rodeway Inn': 2,
#               u'Romantik': 1,
#               u'Room Mate': 15,
#               u'Roomzzz': 1,
#               u'Royal Resorts': 7,
#               u'SACO Apartments': 1,
#               u'Salinas Hot\xe9is e Resorts': 2,
#               u'Sandton Hotels': 6,
#               u'Sava Hotels &amp; Resorts': 12,
#               u'Sbokos Hotel Group': 1,
#               u'Scandic': 1,
#               u'Shaner Hotels': 2,
#               u'Sheraton': 1,
#               u'Solaris Beach Resort': 2,
#               u'Sorat Hotels': 8,
#               u'St. James Hotel Group': 1,
#               u'Starway Hotels': 2,
#               u'Station Casino': 1,
#               u'Stella Di Mare Hotels &amp; Resorts': 1,
#               u'Summit Hotels &amp; Resorts': 1,
#               u'Super 8': 3,
#               u'Supranational': 1,
#               u'Swiss Budget Hotels': 1,
#               u'The Leading Hotels of the World': 3,
#               u'The Peninsula Hotels': 1,
#               u'Titanic Hotels': 7,
#               u'Tropical Hot\xe9is': 1,
#               u'Tsogo Sun-Hotels': 1,
#               u'U Hotels &amp; Resorts': 5,
#               u'Union Ljubljana': 4,
#               u'Upstalsboom': 1,
#               u'Van der Valk Hotels': 20,
#               u'Vincci Hoteles': 20,
#               u'W Hotels': 1,
#               u'WJW Hospitality': 1,
#               u'Westin': 3,
#               u'Worldhotels': 3,
#               u'Worldhotels, Arvena': 1,
#               u'[Plateno Hotels Group] 7Days Inn': 1,
#               u'arcona Management GmbH': 6,
#               u'ibis': 1,
#               u'relexa hotels': 6,
#               u'welcome hotels': 7}),
#  u'TRAVELODGE': defaultdict(int,
#              {u'Comfort Inn': 1,
#               u'Days Inn': 3,
#               u'Doubletree by Hilton': 1,
#               u'Hampton by Hilton': 1,
#               u'Howard Johnson': 1,
#               u'Knights Inn': 2,
#               u'Motel6': 3,
#               'NONE': 11,
#               u'Ramada': 3,
#               u'Red Roof Inn': 1,
#               u'Rodeway Inn': 1,
#               u'Super 8': 3,
#               u'Travelodge': 1,
#               u'Travelodge by Wyndham': 267,
#               u'Travelodge by Wyndham, Shell Vacations Hospitality': 1,
#               u'Wyndham Hotels &amp; Resorts': 1,
#               u'Wyndham Hotels &amp; Resorts, Travelodge': 1}),
#  u'TRAVELODGE UK': defaultdict(int,
#              {u'AC Hotels by Marriott': 1,
#               u'Aloft': 1,
#               u'Britannia Hotels': 1,
#               u'Holiday Inn Express': 3,
#               u'Jurys Inns': 1,
#               u'Marriott Hotels & Resorts': 1,
#               u'Mitchells and Butlers Innkeepers lodge': 1,
#               u'Motel One': 1,
#               'NONE': 27,
#               u'Novotel': 2,
#               u'Park Inn by Radisson': 2,
#               u'Premier Inn': 2,
#               u'Ramada': 1,
#               u'SACO Apartments': 1,
#               u'Travelodge': 12,
#               u'Village Hotels &amp; Leisure Clubs': 2,
#               u'YHA': 1,
#               u'ibis Styles': 1}),
#  u'TRIBUTE PORTFOLIO': defaultdict(int, {u'Tribute Portfolio': 1}),
#  u'TRIDENT HOTELS': defaultdict(int,
#              {u'Lemon Tree Hotels': 1,
#               'NONE': 1,
#               u'Oberoi Hotels &amp; Resorts': 6,
#               u'Oberoi Hotels &amp; Resorts, Trident Hotels': 2}),
#  u'TRU BY HILTON': defaultdict(int, {u'Studio 6': 1}),
#  u'TRUMP HTL COLLECTION': defaultdict(int,
#              {'NONE': 1, u'Trump Hotel Collection': 6}),
#  u'TRYP HOTELS': defaultdict(int,
#              {'NONE': 4,
#               u'Tryp': 18,
#               u'W Hotels': 1,
#               u'Wyndham Hotels &amp; Resorts': 1}),
#  u'TSOGO SUN': defaultdict(int, {u'Tsogo Sun-Hotels': 3}),
#  u'UNIVERSAL ORL RESORT': defaultdict(int,
#              {u'Holiday Inn Express': 1,
#               u'Loews Hotels, Universal Orlando Resort': 3}),
#  u'VICEROY HOTEL GROUP': defaultdict(int,
#              {u'Hostelling International USA': 1, 'NONE': 10}),
#  u'VIENNA HOUSE': defaultdict(int, {'NONE': 1, u'Vienna House': 27}),
#  u'VILLAGE HOTELS': defaultdict(int,
#              {u'Village Hotels &amp; Leisure Clubs': 20}),
#  u'VIRGIN HOTELS': defaultdict(int, {'NONE': 1}),
#  u'W HOTELS': defaultdict(int, {'NONE': 3, u'W Hotels': 9}),
#  u'WALDORF ASTORIA': defaultdict(int,
#              {u'The Peninsula Hotels': 1,
#               u'Waldorf Astoria Hotels &amp; Resorts': 17}),
#  u'WARWICK HOTELS': defaultdict(int,
#              {u'Hilton Hotels & Resorts': 1,
#               'NONE': 13,
#               u'W Hotels': 1,
#               u'Warwick Hotels and Resorts': 2,
#               u'Warwick Hotels and Resorts, Warwick International Hotels and Resorts': 3,
#               u'Warwick International Hotels and Resorts': 6}),
#  u'WESTIN HOTELS': defaultdict(int,
#              {u'Best Western': 1,
#               u'Hanting Inns & Hotels': 1,
#               u'Hilton Hotels & Resorts': 1,
#               'NONE': 5,
#               u'The Ritz-Carlton Company, L.L.C': 1,
#               u'Westin': 50,
#               u'Westin, Crestline Hotels': 1}),
#  u'WHITEBOARD LABS': defaultdict(int,
#              {u'Classic Hotels': 4,
#               u'Crestline Hotels': 1,
#               u'Days Inn': 1,
#               u'Holiday Inn Hotels & Resorts': 2,
#               u'Motel6': 1,
#               'NONE': 91,
#               u'Rodeway Inn': 1,
#               u'Rodeway Inn, Americas Best Value Inn, Red Lion Hotels': 1,
#               u"Victor's Residenz Hotels": 10}),
#  u'WINGATE BY WYNDHAM': defaultdict(int,
#              {u'Embassy Suites Hotels': 1,
#               u'Hilton Hotels & Resorts': 1,
#               u'La Quinta Inn and Suites': 1,
#               u'Microtel Inns &amp; Suites': 1,
#               'NONE': 1,
#               u'Ramada': 1,
#               u'Residence Inn': 1,
#               u'Super 8': 1,
#               u'Wingate by Wyndham': 90,
#               u'Wingate by Wyndham, Aimbridge Hospitality': 1,
#               u'Wingate by Wyndham, GF Hotels': 2,
#               u'Wyndham Hotels &amp; Resorts': 2}),
#  u'WORLDHOTELS': defaultdict(int,
#              {u'AMERON Hotel Collection': 4,
#               u'Adina': 1,
#               u'Amrath Hotels': 1,
#               u'Arp-Hansen Hotel Group': 1,
#               u'Autograph Collection': 1,
#               u'Epoque Hotels': 1,
#               u'Hankyu Hanshin Daiichi Hotels': 2,
#               u'Harbour Plaza Hotels &amp; Resorts': 1,
#               u'JJW Hotels &amp; Resorts': 1,
#               u'LE Royal Hotels': 1,
#               'NONE': 142,
#               u'Nordic Choice Hotels': 1,
#               u'Othon': 1,
#               u'Planetaria Hotels': 1,
#               u'RIHGA Royal Hotel': 3,
#               u'Safir Hotels': 1,
#               u'The LaLiT Suri Hospitality Group': 4,
#               u'Weitzer Hotels': 1,
#               u'Westin': 1,
#               u'Worldhotels': 50,
#               u'Worldhotels, JR East': 1,
#               u'Worldhotels, Weitzer Hotels': 2}),
#  u'WORLDHOTELS UNITED': defaultdict(int,
#              {u'Design Hotels, Nordic Choice Hotels': 1, 'NONE': 1}),
#  u'WYNDHAM HOTELS': defaultdict(int,
#              {u'Aimbridge Hospitality': 1,
#               u'Chateaux et Hotels Collection': 1,
#               u'Days Inn': 1,
#               u'Econo Lodge': 1,
#               u'Hampton by Hilton': 3,
#               u'Hawthorn Suites': 1,
#               u'Hilton Garden Inn': 1,
#               u'Hotel Indigo, GF Hotels': 1,
#               'NONE': 8,
#               u'Nobile Hoteis': 1,
#               u'Residence Inn': 1,
#               u'Wyndham Garden': 14,
#               u'Wyndham Grand': 12,
#               u'Wyndham Hotels &amp; Resorts': 113,
#               u'Wyndham Hotels &amp; Resorts, GHL': 1,
#               u'Wyndham Hotels &amp; Resorts, Nobile Hoteis': 1}),
#  u'WYNDHAM XTRA HOLIDAY': defaultdict(int,
#              {u'Hampton by Hilton': 1,
#               'NONE': 83,
#               u'Shell Vacations Hospitality': 1,
#               u'Travelodge by Wyndham': 1,
#               u'Wyndham Hotels &amp; Resorts': 2}),
#  u'XENIA HOTELLERIE': defaultdict(int,
#              {u'Classic Hotels': 1,
#               u'Excel Hotels and Resorts': 1,
#               u'Il Burcardo - Antiche Dimore Romane': 3,
#               u'Interholiday': 3,
#               u'Interhome': 1,
#               'NONE': 424}),
#  u'XN GLOBAL-RES': defaultdict(int, {'NONE': 17, u'Roomzzz': 2}),
#  u'YOTEL': defaultdict(int, {u'W Hotels': 1}),
#  u'ZAZA RESORTS': defaultdict(int, {'NONE': 2})}

# %%
amdh.bkg_id = amdh.amd_id.apply(lambda i: matches[i] if i in matches else None)
matches_df = amdh.join(bkgh, on='bkg_id', how='inner', rsuffix='_bkg')
matches_df = matches_df[['amd_id', 'bkg_id_bkg',u'name', 'name_bkg', u'chain', 'chain_bkg', 'lat',  u'lng', u'lat_bkg', u'lng_bkg']]
mdf = matches_df
mdf.chain_bkg.fillna('', inplace=True)
len(matches_df)
# Out:
# 91035

# %%
# Explore suspicious chain matches ( Example )
chain_a = "RESIDENCE INN HOTELS"
chain_b = "Marriott Hotels & Resorts"

filter_a = (mdf.chain == chain_a) if chain_a else (mdf.chain.isnull())
filter_b = (mdf.chain_bkg == chain_b) if chain_b else (mdf.chain_bkg.isnull())
mdf[filter_a & filter_b]

# %% [markdown]
# # 4. clean up erroneous chain matches

# %%
chain_matches = load_commented_json('chain_matches_excel_suspicious.json')

# %%
sc = mdf.copy() # candidates to suspicious

sc.name = sc.name.apply(normalize)
sc.name_bkg = sc.name_bkg.apply(normalize)
sc.chain = sc.chain.astype(unicode).apply(normalize)
sc.chain_bkg = sc.chain_bkg.astype(unicode).apply(normalize)

filter_neq_name = sc.name != sc.name_bkg
sc = sc[filter_neq_name]

len(sc)
# Out:
# 47652

# %%
suspicious = pd.DataFrame(data=[],columns=mdf.columns)

for chain_a, d in chain_matches.items():
    for chain_b in d:
        chain_a = normalize(unicode(chain_a))
        chain_b = normalize(unicode(chain_b))
        filter_a = (sc.chain == chain_a) if chain_a != 'none' else (sc.chain.isnull())
        filter_b = (sc.chain_bkg == chain_b) if chain_b != 'none' else (sc.chain_bkg.isnull())
        if chain_a:
            filter_b = filter_b & ~(sc.name_bkg.str.contains(chain_a))
        if chain_b:
            filter_a = filter_a & ~(sc.name.str.contains(chain_b))
            
        suspicious = suspicious.append(sc[filter_a & filter_b])

len(suspicious)
# Out:
# 41464

# %%
def _get_geo_dist(lat1, lng1, lat2, lng2):
    """
        Geographic distance using Haversine formula
    """
    r = 6371000  # Earth radius in meters
    phi1 = math.radians(lat1)
    phi2 = math.radians(lat2)
    lambda1 = math.radians(lng1)
    lambda2 = math.radians(lng2)
    haversin = lambda theta: (1 - math.cos(theta)) / 2.0
    h = haversin(phi2 - phi1) + math.cos(phi1) * math.cos(phi2) * \
        haversin(lambda2 - lambda1)
    c = 2 * math.atan2(math.sqrt(h), math.sqrt(1 - h))
    
    return r * c

vect_geo_dist = np.vectorize(_get_geo_dist)

def row_name_sim(row):
    return get_name_sim(row['name'], row['name_bkg'])

def row_name_sim_sw(row):
    return get_name_sim(row['name'], row['name_bkg'], swap_words=True)

def row_chain_sim(row):
    return get_name_sim(row['chain'], row['chain_bkg'])

def row_chain_sim_sw(row):
    return get_name_sim(row['chain'], row['chain_bkg'], swap_words=True)

# %%
s = suspicious

# %%
s['dist'] = vect_geo_dist(s.lat, s.lng, s.lat_bkg, s.lng_bkg)

# %%
s['name_sim'] = s.apply(row_name_sim, axis=1)

# %%
s['name_sim_sw'] = s.apply(row_name_sim_sw, axis=1)

# %%
s['chain_sim'] = s.apply(row_chain_sim, axis=1)

# %%
s['chain_sim_sw'] = s.apply(row_chain_sim_sw, axis=1)

# %%
def row_name_included(row):
    n = normalize(row['name']).replace(' ', '')    
    nb = normalize(row['name_bkg']).replace(' ', '')
    return (n in nb) or (nb in n)

def row_chain_included(row):
    n = normalize(row['chain']).replace(' ', '')    
    nb = normalize(row['chain_bkg']).replace(' ', '')
    return (n and n in nb) or (nb and nb in n)

# %%
s['name_included'] = s.apply(row_name_included, axis=1)

# %%
s['chain_included'] = s.apply(row_chain_included, axis=1)

# %%
s.sample(50)
# Out:
#                amd_id  bkg_id_bkg                                     name  \
# HSXMNAFX  700206284.0   1548038.0                           add inn xiamen
# YXMUCHHM  700262462.0   1292008.0                          harrys muenchen
# HSDUSAIV  700125142.0    287918.0                      sankt andreas garni
# YXLEDRBB  700074651.0     40739.0                   rinaldi petrogradskaya
# HSZSOACC  700029896.0     67447.0              werrapark haus frankenblick
# HSBJSBIZ  700127717.0    535607.0                       broadcasting tower
# HSZPRAAH  700088131.0     76935.0                        floetzinger braeu
# YXCHS857  700081907.0     58452.0                              seaside inn
# WVNAP009  700038556.0     86982.0                    club due torri maioni
# HSCEKABA  700169056.0    308814.0                         solnechny co heh
# SMDUSHAF  700188049.0    545596.0                innside duesseldorf hafen
# HSINNDML  700189231.0    240081.0                                  montana
# HHORL767  700113551.0     79797.0                    las palmeras hgv club
# HSQPAADL  700179744.0    264239.0                  antica corte marchesini
# HSTAOARB  700075765.0   1375664.0                     debao garden qingdao
# HSFLRBAB  700250992.0    867215.0             casale podernovo agriturismo
# HSSZWADS  700269048.0   1056572.0                             zur seemoewe
# HSRZEAEW  700224862.0    285865.0                    podzamcze restauracja
# HSCKGAQZ  700272745.0   1486902.0                   hanting guanyin bridge
# HSFKBAGG  700125568.0    183461.0               am kurgarten erlebnishotel
# HSZQFAAQ  700088251.0     64477.0                                    kugel
# HSZCRAAJ  700088153.0     72554.0                                kohlmeier
# HIALBD02  700068319.0    325743.0           holiday inn johnstown gloversv
# HSISTAMS  700025408.0     86224.0                             celal sultan
# YXPARLRM  700092140.0     57712.0                    htl relais montmartre
# HSNGBAJG  700206222.0    251916.0                             han s ningbo
# HSKLUBGM  700154768.0    292042.0     feriendorf kirchleitn dorf kleinwild
# HSOBFAAU  700072958.0    388400.0                       koenigslinde garni
# HSJILAAV  700211099.0   1597038.0       tiger dna business songyuan statio
# HSBJSAVT  700185315.0   1596131.0                       beijing cheng ming
# HSBJSATZ  700196761.0    408946.0           beijing zhongguancun shijia ho
# HSLCVACH  700062249.0     81180.0                                da carlos
# YXQPLABN  700269869.0    375831.0                                 sky blue
# HSBUDAWX  700239050.0   1172609.0                         bastion budapest
# HSQVQABJ  700148166.0    247051.0                      heideparadies garni
# HXTCLGN9  700037180.0    292447.0               hampton tuscaloosa east al
# HSQMEAEA  700038638.0    242139.0                    club valtur portorosa
# YXYSCHLP  700230021.0    257838.0                                president
# HSMUCBDU  700194550.0    428847.0                     gs geiger good sleep
# HSSTRAJK  700146734.0    176093.0                       hermanns neue post
# HSKLUAWA  700124862.0    582320.0                       zum kramer gasthof
# HSZCBADK  700126013.0     69015.0                                 centgraf
# ONCGNDEU  700086480.0     63891.0                           deutsches haus
# HSYNTAEF  700317642.0   1465732.0                        lijiaoqiao yantai
# LGFRAMPL  700022453.0     62223.0             lindner main plaza frankfurt
# YXHYN197  700082738.0    260350.0                     new century tai zhou
# HSVKBABF  700074607.0    260565.0                        traube restaurant
# HSZINAAJ  700060724.0     66295.0                         parkhotel am see
# HSQXZAJC  502277292.0    292088.0  all inclusive familotel st johanner hof
# HSWVNABA  700260265.0    271127.0            strandhotels seestern delphin
#
#                                       name_bkg              chain  \
# HSXMNAFX                   qininn xiamen gucuo            hrs gds
# YXMUCHHM                       harry s munchen             synxis
# HSDUSAIV                         sankt andreas            hrs gds
# YXLEDRBB           rinaldi petrogradskaya side             synxis
# HSZSOACC                werrapark frankenblick            hrs gds
# HSBJSBIZ            beijing broadcasting tower            hrs gds
# HSZPRAAH               gasthof flotzinger brau            hrs gds
# YXCHS857             seaside inn isle of palms             synxis
# WVNAP009                        club due torri        travelclick
# HSCEKABA                            solnechniy            hrs gds
# SMDUSHAF        innside melia dusseldorf hafen         melia intl
# HSINNDML                          haus montana            hrs gds
# HHORL767     las palmeras hltn grand vacations         hltn corpo
# HSQPAADL       albergo antica corte marchesini            hrs gds
# HSTAOARB                    qingdao garden vip            hrs gds
# HSFLRBAB                      casale podernovo            hrs gds
# HSSZWADS                           zur seemowe            hrs gds
# HSRZEAEW                             podzamcze            hrs gds
# HSCKGAQZ                 injoy kwan yin bridge            hrs gds
# HSFKBAGG        bsw erlebnishotel am kurgarten            hrs gds
# HSZQFAAQ                      restaurant kugel            hrs gds
# HSZCRAAJ                     gasthof kohlmeier            hrs gds
# HIALBD02        super 8 johnstown gloversville        holiday inn
# HSISTAMS                            gul sultan            hrs gds
# YXPARLRM                     relais montmartre             synxis
# HSNGBAJG                        shangri ningbo            hrs gds
# HSKLUBGM  kirchleitn feriendorf dorf kleinwild            hrs gds
# HSOBFAAU                           konigslinde            hrs gds
# HSJILAAV                     qianyuan business            hrs gds
# HSBJSAVT                       beijing haoyang            hrs gds
# HSBJSATZ            ehome zhongguancun beijing            hrs gds
# HSLCVACH                  ristorante da carlos            hrs gds
# YXQPLABN                                   sym             synxis
# HSBUDAWX                        oasis budapest            hrs gds
# HSQVQABJ                         heideparadies            hrs gds
# HXTCLGN9           hampton inn tuscaloosa east       hampton inns
# HSQMEAEA                     corallo portorosa            hrs gds
# YXYSCHLP                  president sherbrooke             synxis
# HSMUCBDU                                    gs            hrs gds
# HSSTRAJK                   hermann s neue post            hrs gds
# HSKLUAWA                    gasthof zum kramer            hrs gds
# HSZCBADK                      gasthof centgraf            hrs gds
# ONCGNDEU                  garni deutsches haus          reconline
# HSYNTAEF                     yantai lijiaoqiao            hrs gds
# LGFRAMPL                    lindner main plaza  lindner htls rsts
# YXHYN197                   new century taizhou             synxis
# HSVKBABF                     restaurant traube            hrs gds
# HSZINAAJ                      parkhotel gunten            hrs gds
# HSQXZAJC             familotel st johanner hof            hrs gds
# HSWVNABA  akzent strandhotels seestern delphin            hrs gds
#
#                      chain_bkg      lat        lng    lat_bkg     lng_bkg  \
# HSXMNAFX                        24.4259  118.12358  24.426950  118.123949
# YXMUCHHM                        48.1796   11.50684  48.179500   11.506132
# HSDUSAIV                        51.2269    6.77431  51.227007    6.774441
# YXLEDRBB                        59.9633   30.30765  59.963282   30.306795
# HSZSOACC                        50.4993   10.90107  50.499324   10.900873
# HSBJSBIZ                        39.9074  116.44191  39.907368  116.443335
# HSZPRAAH                        47.8575   12.12823  47.857278   12.128084
# YXCHS857                        32.7845  -79.78975  32.784562  -79.790414
# WVNAP009                        40.6802   14.62695  40.644178   14.649024
# HSCEKABA                         55.148   61.36295  55.148082   61.363244
# SMDUSHAF         innside melia  51.2151    6.75027  51.215010    6.750350
# HSINNDML                        47.3973   10.88751  47.397418   10.887481
# HHORL767  hltn grand vacations  28.4344  -81.45953  28.433761  -81.459868
# HSQPAADL                        45.3595   12.09257  45.359611   12.093193
# HSTAOARB                        36.0658  120.41253  36.063376  120.414276
# HSFLRBAB                        43.5403   10.66989  43.536572   10.667212
# HSSZWADS                         53.998   11.44116  53.997940   11.440920
# HSRZEAEW                        49.9892   21.00101  49.989270   21.001074
# HSCKGAQZ                        29.5719  106.53157  29.569891  106.533672
# HSFKBAGG                        48.5029    8.37398  48.503068    8.373891
# HSZQFAAQ                        49.7219    6.57923  49.721915    6.579351
# HSZCRAAJ                         48.406   11.61674  48.406024   11.617129
# HIALBD02               super 8   43.022  -74.36059  43.021667  -74.362349
# HSISTAMS                        41.0081   28.97561  41.005755   28.980694
# YXPARLRM                        48.8853    2.33362  48.885384    2.333545
# HSNGBAJG   shangri amp resorts  29.8663  121.56992  29.867580  121.561865
# HSKLUBGM                        46.8258   13.79316  46.841810   13.765287
# HSOBFAAU                        47.6741   12.01364  47.674081   12.013507
# HSJILAAV                        45.1117  124.81942  45.139131  124.793867
# HSBJSAVT                        39.8688  116.38454  39.871804  116.389160
# HSBJSATZ                        39.9777  116.31267  39.975994  116.305947
# HSLCVACH                        43.7766   10.45919  43.776579   10.459872
# YXQPLABN                        44.9376   26.00989  44.889644   26.044550
# HSBUDAWX                        47.4895   19.06013  47.488160   19.065182
# HSQVQABJ                        52.9867    9.84624  52.986868    9.846277
# HXTCLGN9          hampton hltn  33.1736  -87.44211  33.175140  -87.449368
# HSQMEAEA                        38.1224   15.10888  38.125712   15.113325
# YXYSCHLP                        45.3929  -71.95505  45.393188  -71.956292
# HSMUCBDU                        48.1028   11.53105  48.102752   11.531036
# HSSTRAJK                        48.7131    8.74165  48.713812    8.742004
# HSKLUAWA                         46.849   14.28543  46.849145   14.285976
# HSZCBADK                        49.7162    9.26496  49.715301    9.264727
# ONCGNDEU     privatecityhotels  50.7393    7.09926  50.739334    7.099356
# HSYNTAEF                        37.5616  121.35559  37.561461  121.355388
# LGFRAMPL   lindner amp resorts  50.1061    8.69554  50.106065    8.695520
# YXHYN197                        28.6466  121.42372  28.643227  121.428607
# HSVKBABF                        46.5954   10.54483  46.595247   10.544847
# HSZINAAJ                        46.7124    7.70254  46.712375    7.702555
# HSQXZAJC                         47.523   12.42088  47.523438   12.420777
# HSWVNABA                        53.5128    8.14095  53.512864    8.141068
#
#                  dist  name_sim  name_sim_sw  chain_sim  chain_sim_sw  \
# HSXMNAFX   122.569637  0.606061     0.666667   0.000000      1.000000
# YXMUCHHM    53.046586  0.933333     0.928571   0.000000      1.000000
# HSDUSAIV    14.153666  0.812500     1.000000   0.000000      1.000000
# YXLEDRBB    47.609014  0.897959     1.000000   0.000000      1.000000
# HSZSOACC    14.048632  0.897959     1.000000   0.000000      1.000000
# HSBJSBIZ   121.715344  0.818182     1.000000   0.000000      1.000000
# HSZPRAAH    22.961097  0.750000     0.937500   0.000000      1.000000
# YXCHS857    62.194719  0.611111     1.000000   0.000000      1.000000
# WVNAP009  4418.111669  0.800000     1.000000   0.000000      1.000000
# HSCEKABA    21.829033  0.692308     0.947368   0.000000      1.000000
# SMDUSHAF    11.454194  0.872727     0.979592   0.434783      0.695652
# HSINNDML    16.582097  0.736842     1.000000   0.000000      1.000000
# HHORL767    80.408948  0.629630     0.736842   0.466667      0.600000
# HSQPAADL    49.116821  0.851852     1.000000   0.000000      1.000000
# HSTAOARB   307.136400  0.631579     0.736842   0.000000      1.000000
# HSFLRBAB   463.456207  0.727273     1.000000   0.000000      1.000000
# HSSZWADS    16.037722  0.956522     0.956522   0.000000      1.000000
# HSRZEAEW     8.100941  0.600000     1.000000   0.000000      1.000000
# HSCKGAQZ   297.904648  0.604651     0.648649   0.000000      1.000000
# HSFKBAGG    20.800456  0.500000     1.000000   0.000000      1.000000
# HSZQFAAQ     9.147879  0.476190     1.000000   0.000000      1.000000
# HSZCRAAJ    28.699033  0.692308     1.000000   0.000000      1.000000
# HIALBD02   148.871152  0.666667     0.633333   0.111111      0.111111
# HSISTAMS   501.753819  0.727273     0.727273   0.000000      1.000000
# YXPARLRM     8.984207  0.894737     1.000000   0.000000      1.000000
# HSNGBAJG   789.085652  0.769231     0.727273   0.307692      0.428571
# HSKLUBGM  2770.707354  0.694444     1.000000   0.000000      1.000000
# HSOBFAAU    10.036104  0.758621     0.956522   0.000000      1.000000
# HSJILAAV  3653.738537  0.470588     0.823529   0.000000      1.000000
# HSBJSAVT   516.018381  0.666667     0.785714   0.000000      1.000000
# HSBJSATZ   604.494255  0.642857     0.938776   0.000000      1.000000
# HSLCVACH    54.810596  0.620690     1.000000   0.000000      1.000000
# YXQPLABN  5993.277092  0.363636     0.666667   0.000000      1.000000
# HSBUDAWX   408.626167  0.800000     0.533333   0.000000      1.000000
# HSQVQABJ    19.934728  0.812500     1.000000   0.000000      1.000000
# HXTCLGN9   697.149879  0.867925     0.867925   0.750000      0.750000
# HSQMEAEA   535.561472  0.684211     0.774194   0.000000      1.000000
# YXYSCHLP   102.103091  0.620690     1.000000   0.000000      1.000000
# HSMUCBDU     1.379286  0.181818     1.000000   0.000000      1.000000
# HSSTRAJK    87.530113  0.972973     0.971429   0.000000      1.000000
# HSKLUAWA    43.817639  0.555556     1.000000   0.000000      1.000000
# HSZCBADK   101.413614  0.666667     1.000000   0.000000      1.000000
# ONCGNDEU     6.766097  0.823529     1.000000   0.384615      0.384615
# HSYNTAEF    22.161614  0.588235     1.000000   0.000000      1.000000
# LGFRAMPL     1.481566  0.782609     1.000000   0.722222      0.722222
# YXHYN197   606.712266  0.974359     0.974359   0.000000      1.000000
# HSVKBABF    20.344669  0.588235     1.000000   0.000000      1.000000
# HSZINAAJ     3.004741  0.687500     0.720000   0.000000      1.000000
# HSQXZAJC    44.946938  0.781250     1.000000   0.000000      1.000000
# HSWVNABA    11.315766  0.892308     1.000000   0.000000      1.000000
#
#          name_included chain_included
# HSXMNAFX         False
# YXMUCHHM         False
# HSDUSAIV          True
# YXLEDRBB          True
# HSZSOACC         False
# HSBJSBIZ          True
# HSZPRAAH         False
# YXCHS857          True
# WVNAP009          True
# HSCEKABA         False
# SMDUSHAF         False          False
# HSINNDML          True
# HHORL767         False          False
# HSQPAADL          True
# HSTAOARB         False
# HSFLRBAB          True
# HSSZWADS         False
# HSRZEAEW          True
# HSCKGAQZ         False
# HSFKBAGG         False
# HSZQFAAQ          True
# HSZCRAAJ          True
# HIALBD02         False          False
# HSISTAMS         False
# YXPARLRM          True
# HSNGBAJG         False          False
# HSKLUBGM         False
# HSOBFAAU         False
# HSJILAAV         False
# HSBJSAVT         False
# HSBJSATZ         False
# HSLCVACH          True
# YXQPLABN         False
# HSBUDAWX         False
# HSQVQABJ          True
# HXTCLGN9         False          False
# HSQMEAEA         False
# YXYSCHLP          True
# HSMUCBDU          True
# HSSTRAJK          True
# HSKLUAWA         False
# HSZCBADK          True
# ONCGNDEU          True          False
# HSYNTAEF         False
# LGFRAMPL          True          False
# YXHYN197          True
# HSVKBABF         False
# HSZINAAJ         False
# HSQXZAJC          True
# HSWVNABA          True

# %%
suspicious.to_excel('suspicious_matches_excel.xls', index=False)

# %% [markdown]
# # 5. remove suspicious matches and save to public matches file

# %%
len(matches)
# Out:
# 85805

# %%
clean_matches = {k:v for k,v in matches.items() if k not in suspicious.amd_id.values}

len(clean_matches)
# Out:
# 77314

# %%
# percentage matched
len(clean_matches) * 1.0 / len(amdh)
# Out:
# 0.5494602335316149

# %%
json_dump_unicode(clean_matches,'matches_excel_clean.json')

# %% [markdown]
# # 6. Compute livingscores and append columns to excel file

# %%
amdh_full = pd.read_excel('./Amadeus All Properties - FEB 2017 17022017 .xlsx', header=0, index_col='PROPERTY_CODE', skiprows=1)

# %%
m = clean_matches

# %% [markdown]
# ## Load livingscores for all Booking.com properties

# %%
with open('livingscore.json') as f:
    lvs = json.load(f)

# %% [markdown]
# ## Map Livingrooms IDs to Amadeus codes

# %%
conn = get_amd_db_conn()
cur = conn.cursor()
query = """SELECT pr.id, pr.position, pr.name, v."vendorId"
           FROM public."Properties" pr
           JOIN public."VendorIds" v
           ON pr.id = v.relation
           WHERE v.vendor = 'amadeus'
        """
cur.execute(query)
lrid_to_amdid = {}
for r in cur.fetchall():
    lrid_to_amdid[r[0]] = r[-1]

amdid_to_lrid = {k:v for v,k in lrid_to_amdid.items()}

# %%
m.items()[0]
# Out:
# (u'700151432.0', 350152)

# %%
amdid_to_lrid.items()[0]
# Out:
# ('YOFAYD02', '0afb7c67-406a-42ff-bfe1-e340df973eed')

# %%
amdh_full['DUPE_POOL_ID'].values
# Out:
# array([  5.03919399e+08,   5.03948101e+08,   5.03929932e+08, ...,
#          7.00144748e+08,              nan,              nan])

# %%
matches_ls = {}
for did, bkgid in m.items():
    matches_ls[did] = lvs.get(str(bkgid))
matches_ls = {k:v for k,v in matches_ls.items() if v}

def max_ls(did):
    ls = matches_ls.get(str(did))
    if ls:
        return max(ls)
    else:
        return None

def min_ls(did):
    ls = matches_ls.get(str(did))
    if ls:
        return min(ls)
    else:
        return None

def avg_ls(did):
    ls = matches_ls.get(str(did))
    if ls:
        return np.mean(ls)
    else:
        return None

amdh_full['LIVINGSCORE_MAX'] = amdh_full['DUPE_POOL_ID'].apply(max_ls)
amdh_full['LIVINGSCORE_MIN'] = amdh_full['DUPE_POOL_ID'].apply(min_ls)
amdh_full['LIVINGSCORE_AVG'] = amdh_full['DUPE_POOL_ID'].apply(avg_ls)

# %%
def did_to_bkg(did):
    return m.get(str(did))

amdh_full['Booking ID'] = amdh_full['DUPE_POOL_ID'].apply(did_to_bkg)

# %%
amdh_full.to_excel('Amadeus All Properties - FEB 2017 17022017 with Livingscores .xlsx')
