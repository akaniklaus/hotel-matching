# %%
# %load_ext autoreload
# %autoreload 2

from amd_bkg_matchids import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. load Amadeus & Booking hotels

# %%
amdh, bkgh, matches, geo_index, namdh = initialize_matching(True)
# Out:
# Loading Amadeus hotels
# Loaded 6007 hotels
# Loading Booking hotels
# Loaded 882902 hotels
# 6007 Amadeus hotels left to match to 882902 Booking hotels
# Building Geo Index

# %% [markdown]
# # 3. generate candidates

# %%
candidates = extract_candidates(amdh[:1000], geo_index, 6, 0.7, namdh)
# Out:
# 100.00 %

# %%
candidates
# Out:
# {'005abffd-22b2-40cb-8e47-9f0a3dabde1f': [{'amd_id': '005abffd-22b2-40cb-8e47-9f0a3dabde1f',
#    'bkg_id': 1194989,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Baymont Inn &amp; Suites',
#    'dist': 0.0005285519384731723,
#    'name': u'BAYMONT INN & SUITES RAPID CIT',
#    'name_bkg': u'Baymont Inn & Suites Rapid City',
#    'name_sim': 0.9130434782608695,
#    'name_sim_sw': 0.9803921568627451},
#   {'amd_id': '005abffd-22b2-40cb-8e47-9f0a3dabde1f',
#    'bkg_id': 301390,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Microtel Inns &amp; Suites',
#    'dist': 4.275018226990847,
#    'name': u'BAYMONT INN & SUITES RAPID CIT',
#    'name_bkg': u'Microtel Inn & Suites by Wyndham Rapid City',
#    'name_sim': 0.6181818181818182,
#    'name_sim_sw': 0.8695652173913043},
#   {'amd_id': '005abffd-22b2-40cb-8e47-9f0a3dabde1f',
#    'bkg_id': 677063,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Main Stay Suites',
#    'dist': 1.365533629544177,
#    'name': u'BAYMONT INN & SUITES RAPID CIT',
#    'name_bkg': u'MainStay Suites Rapid City',
#    'name_sim': 0.6046511627906976,
#    'name_sim_sw': 0.8},
#   {'amd_id': '005abffd-22b2-40cb-8e47-9f0a3dabde1f',
#    'bkg_id': 461441,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'La Quinta Inn and Suites',
#    'dist': 0.21247711583905604,
#    'name': u'BAYMONT INN & SUITES RAPID CIT',
#    'name_bkg': u'La Quinta Inn & Suites Rapid City',
#    'name_sim': 0.7111111111111111,
#    'name_sim_sw': 0.7906976744186046},
#   {'amd_id': '005abffd-22b2-40cb-8e47-9f0a3dabde1f',
#    'bkg_id': 1618186,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Holiday Inn Express',
#    'dist': 4.268849705652347,
#    'name': u'BAYMONT INN & SUITES RAPID CIT',
#    'name_bkg': u'Holiday Inn Express & Suites Rapid City',
#    'name_sim': 0.6956521739130435,
#    'name_sim_sw': 0.7906976744186046},
#   {'amd_id': '005abffd-22b2-40cb-8e47-9f0a3dabde1f',
#    'bkg_id': 501368,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Super 8',
#    'dist': 4.4813829109894945,
#    'name': u'BAYMONT INN & SUITES RAPID CIT',
#    'name_bkg': u'Super 8 Rapid City',
#    'name_sim': 0.42105263157894735,
#    'name_sim_sw': 0.7741935483870968},
#   {'amd_id': '005abffd-22b2-40cb-8e47-9f0a3dabde1f',
#    'bkg_id': 516550,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Rodeway Inn',
#    'dist': 4.277657799543299,
#    'name': u'BAYMONT INN & SUITES RAPID CIT',
#    'name_bkg': u'Rodeway Inn Rapid City',
#    'name_sim': 0.5714285714285714,
#    'name_sim_sw': 0.7692307692307693},
#   {'amd_id': '005abffd-22b2-40cb-8e47-9f0a3dabde1f',
#    'bkg_id': 1397303,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Residence Inn',
#    'dist': 0.3291396420637133,
#    'name': u'BAYMONT INN & SUITES RAPID CIT',
#    'name_bkg': u'Residence Inn by Marriott Rapid City',
#    'name_sim': 0.5116279069767442,
#    'name_sim_sw': 0.7619047619047619},
#   {'amd_id': '005abffd-22b2-40cb-8e47-9f0a3dabde1f',
#    'bkg_id': 290791,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Hampton by Hilton',
#    'dist': 4.26944288591029,
#    'name': u'BAYMONT INN & SUITES RAPID CIT',
#    'name_bkg': u'Hampton Inn Rapid City',
#    'name_sim': 0.6666666666666666,
#    'name_sim_sw': 0.7428571428571429}],
#  '0072ec51-6db8-45e8-970f-4b8da5384c8d': [{'amd_id': '0072ec51-6db8-45e8-970f-4b8da5384c8d',
#    'bkg_id': 316766,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Baymont Inn &amp; Suites',
#    'dist': 0.07883069813887297,
#    'name': u'BAYMONT INN & SUITES SOUTH HAV',
#    'name_bkg': u'Baymont Inn & Suites South Haven',
#    'name_sim': 0.9615384615384616,
#    'name_sim_sw': 0.9615384615384616},
#   {'amd_id': '0072ec51-6db8-45e8-970f-4b8da5384c8d',
#    'bkg_id': 360526,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Hampton by Hilton',
#    'dist': 0.07895623472088785,
#    'name': u'BAYMONT INN & SUITES SOUTH HAV',
#    'name_bkg': u'Hampton Inn South Haven',
#    'name_sim': 0.75,
#    'name_sim_sw': 0.8181818181818182},
#   {'amd_id': '0072ec51-6db8-45e8-970f-4b8da5384c8d',
#    'bkg_id': 190614,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Holiday Inn Express',
#    'dist': 0.3860722520758858,
#    'name': u'BAYMONT INN & SUITES SOUTH HAV',
#    'name_bkg': u'Holiday Inn Express Hotel & Suites South Haven',
#    'name_sim': 0.7692307692307693,
#    'name_sim_sw': 0.7727272727272727},
#   {'amd_id': '0072ec51-6db8-45e8-970f-4b8da5384c8d',
#    'bkg_id': 490340,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Comfort Suites',
#    'dist': 0.4891523086157505,
#    'name': u'BAYMONT INN & SUITES SOUTH HAV',
#    'name_bkg': u'Comfort Suites South Haven',
#    'name_sim': 0.6666666666666666,
#    'name_sim_sw': 0.7272727272727273}],
#  '00aa95e9-b5e5-43a6-b2ef-edf03409d7f6': [{'amd_id': '00aa95e9-b5e5-43a6-b2ef-edf03409d7f6',
#    'bkg_id': 659316,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Baymont Inn &amp; Suites',
#    'dist': 0.02351945968728987,
#    'name': u'BAYMONT INN & SUITES WARNER RO',
#    'name_bkg': u'Baymont Inn and Suites - Warner Robins',
#    'name_sim': 0.9259259259259259,
#    'name_sim_sw': 0.9361702127659575},
#   {'amd_id': '00aa95e9-b5e5-43a6-b2ef-edf03409d7f6',
#    'bkg_id': 289660,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Hampton by Hilton',
#    'dist': 2.060969606541682,
#    'name': u'BAYMONT INN & SUITES WARNER RO',
#    'name_bkg': u'Hampton Inn Warner Robins',
#    'name_sim': 0.72,
#    'name_sim_sw': 0.782608695652174},
#   {'amd_id': '00aa95e9-b5e5-43a6-b2ef-edf03409d7f6',
#    'bkg_id': 435846,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Country Inns &amp; Suites',
#    'dist': 1.4313239852525281,
#    'name': u'BAYMONT INN & SUITES WARNER RO',
#    'name_bkg': u'Country Inn & Suites - Warner Robbins',
#    'name_sim': 0.7636363636363637,
#    'name_sim_sw': 0.7636363636363637},
#   {'amd_id': '00aa95e9-b5e5-43a6-b2ef-edf03409d7f6',
#    'bkg_id': 457793,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'La Quinta Inn and Suites',
#    'dist': 2.619425869985968,
#    'name': u'BAYMONT INN & SUITES WARNER RO',
#    'name_bkg': u'La Quinta Inn & Suites Warner Robins - Robins AFB',
#    'name_sim': 0.625,
#    'name_sim_sw': 0.76},
#   {'amd_id': '00aa95e9-b5e5-43a6-b2ef-edf03409d7f6',
#    'bkg_id': 1618148,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Holiday Inn Express',
#    'dist': 2.1679193259148883,
#    'name': u'BAYMONT INN & SUITES WARNER RO',
#    'name_bkg': u'Holiday Inn Express & Suites Warner Robins North West',
#    'name_sim': 0.6153846153846154,
#    'name_sim_sw': 0.7407407407407407},
#   {'amd_id': '00aa95e9-b5e5-43a6-b2ef-edf03409d7f6',
#    'bkg_id': 433691,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Americas Best Value Inn, Red Lion Hotels',
#    'dist': 4.684972570817382,
#    'name': u'BAYMONT INN & SUITES WARNER RO',
#    'name_bkg': u'Americas Best Value Inn - Warner Robins',
#    'name_sim': 0.5614035087719298,
#    'name_sim_sw': 0.723404255319149},
#   {'amd_id': '00aa95e9-b5e5-43a6-b2ef-edf03409d7f6',
#    'bkg_id': 340942,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Days Inn',
#    'dist': 0.05132162851346855,
#    'name': u'BAYMONT INN & SUITES WARNER RO',
#    'name_bkg': u'Days Inn Warner Robins near Robins AFB',
#    'name_sim': 0.5079365079365079,
#    'name_sim_sw': 0.723404255319149},
#   {'amd_id': '00aa95e9-b5e5-43a6-b2ef-edf03409d7f6',
#    'bkg_id': 321417,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Super 8',
#    'dist': 2.615450842268054,
#    'name': u'BAYMONT INN & SUITES WARNER RO',
#    'name_bkg': u'Super 8 Warner Robins',
#    'name_sim': 0.5217391304347826,
#    'name_sim_sw': 0.7058823529411765}],
#  '015ce37b-c2d2-440d-9216-cf044a6d390a': [{'amd_id': '015ce37b-c2d2-440d-9216-cf044a6d390a',
#    'bkg_id': 335138,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Baymont Inn &amp; Suites',
#    'dist': 0.09273269917809411,
#    'name': u'BAYMONT INN & SUITES DALTON',
#    'name_bkg': u'Baymont Inn & Suites Dalton',
#    'name_sim': 1.0,
#    'name_sim_sw': 1.0},
#   {'amd_id': '015ce37b-c2d2-440d-9216-cf044a6d390a',
#    'bkg_id': 333128,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Country Inns &amp; Suites',
#    'dist': 3.956397720148428,
#    'name': u'BAYMONT INN & SUITES DALTON',
#    'name_bkg': u'Country Inn and Suites Dalton',
#    'name_sim': 0.8181818181818182,
#    'name_sim_sw': 0.85},
#   {'amd_id': '015ce37b-c2d2-440d-9216-cf044a6d390a',
#    'bkg_id': 512956,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Days Inn',
#    'dist': 3.778863531241464,
#    'name': u'BAYMONT INN & SUITES DALTON',
#    'name_bkg': u'Days Inn Dalton',
#    'name_sim': 0.7027027027027027,
#    'name_sim_sw': 0.8},
#   {'amd_id': '015ce37b-c2d2-440d-9216-cf044a6d390a',
#    'bkg_id': 456852,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'La Quinta Inn and Suites',
#    'dist': 3.69707939933522,
#    'name': u'BAYMONT INN & SUITES DALTON',
#    'name_bkg': u'La Quinta Inn & Suites Dalton',
#    'name_sim': 0.7906976744186046,
#    'name_sim_sw': 0.7777777777777778},
#   {'amd_id': '015ce37b-c2d2-440d-9216-cf044a6d390a',
#    'bkg_id': 489626,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Comfort Inn',
#    'dist': 4.023574292041075,
#    'name': u'BAYMONT INN & SUITES DALTON',
#    'name_bkg': u'Comfort Inn & Suites Dalton',
#    'name_sim': 0.7727272727272727,
#    'name_sim_sw': 0.7727272727272727},
#   {'amd_id': '015ce37b-c2d2-440d-9216-cf044a6d390a',
#    'bkg_id': 417737,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Motel6',
#    'dist': 0.1460814612433203,
#    'name': u'BAYMONT INN & SUITES DALTON',
#    'name_bkg': u'Motel 6 - Dalton',
#    'name_sim': 0.4666666666666667,
#    'name_sim_sw': 0.75},
#   {'amd_id': '015ce37b-c2d2-440d-9216-cf044a6d390a',
#    'bkg_id': 489641,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Quality Inn',
#    'dist': 3.4615526521938,
#    'name': u'BAYMONT INN & SUITES DALTON',
#    'name_bkg': u'Quality Inn Dalton',
#    'name_sim': 0.65,
#    'name_sim_sw': 0.75},
#   {'amd_id': '015ce37b-c2d2-440d-9216-cf044a6d390a',
#    'bkg_id': 188426,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Hampton by Hilton',
#    'dist': 4.12396891080569,
#    'name': u'BAYMONT INN & SUITES DALTON',
#    'name_bkg': u'Hampton Inn Dalton',
#    'name_sim': 0.75,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '015ce37b-c2d2-440d-9216-cf044a6d390a',
#    'bkg_id': 532724,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Howard Johnson',
#    'dist': 3.346673387377444,
#    'name': u'BAYMONT INN & SUITES DALTON',
#    'name_bkg': u'Howard Johnson Dalton',
#    'name_sim': 0.48484848484848486,
#    'name_sim_sw': 0.7058823529411765}],
#  '01699264-ed02-49a5-8d2d-e5ae83eb3d7d': [{'amd_id': '01699264-ed02-49a5-8d2d-e5ae83eb3d7d',
#    'bkg_id': 511458,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 4.793220472167854,
#    'name': u'EXTENDED STAY AMERICA OKLAHOMA',
#    'name_bkg': u'Extended Stay America - Oklahoma City - Northwest',
#    'name_sim': 0.8571428571428571,
#    'name_sim_sw': 1.0},
#   {'amd_id': '01699264-ed02-49a5-8d2d-e5ae83eb3d7d',
#    'bkg_id': 517420,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.25394710339416354,
#    'name': u'EXTENDED STAY AMERICA OKLAHOMA',
#    'name_bkg': u'Extended Stay America - Oklahoma City - NW Expressway',
#    'name_sim': 0.8108108108108109,
#    'name_sim_sw': 1.0}],
#  '017063ac-bf02-4865-8af4-9aafaa7a2c07': [{'amd_id': '017063ac-bf02-4865-8af4-9aafaa7a2c07',
#    'bkg_id': 518869,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.4337272985405974,
#    'name': u'EXTENDED STAY AMERICA FT JACKS',
#    'name_bkg': u'Extended Stay America - Columbia - Ft. Jackson',
#    'name_sim': 0.8450704225352113,
#    'name_sim_sw': 0.967741935483871}],
#  '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87': [{'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 87475,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.11415640403948239,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Antique Apartments Plac Szczepa\u0144ski',
#    'name_sim': 0.45161290322580644,
#    'name_sim_sw': 1.0},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 362578,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.008134184392199808,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Antique Apartments Old Town',
#    'name_sim': 0.6086956521739131,
#    'name_sim_sw': 1.0},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1338446,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.113072986241296,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'',
#    'name_sim': 0.0,
#    'name_sim_sw': 1.0},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 844618,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.0233074831756277,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Msc Apartments Angel City Krakow',
#    'name_sim': 0.2608695652173913,
#    'name_sim_sw': 0.8235294117647058},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 313952,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.0127226852314222,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'La Gioia Chic Angel Apartments',
#    'name_sim': 0.2608695652173913,
#    'name_sim_sw': 0.8235294117647058},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 500650,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7633793181861184,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Angel Plaza Apartments',
#    'name_sim': 0.3333333333333333,
#    'name_sim_sw': 0.8235294117647058},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1885637,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.8246316909671986,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'AR Apartments - Angel Center Krak\xf3w',
#    'name_sim': 0.20689655172413793,
#    'name_sim_sw': 0.8235294117647058},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 825396,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': u'Amstra Luxury Apartments',
#    'dist': 0.812066445527343,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Wawel Angel Plaza Apartments by Amstra Luxury Apartments',
#    'name_sim': 0.15789473684210525,
#    'name_sim_sw': 0.8235294117647058},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1578879,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.0519021406265268,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Friendhouse Apartments Angel City',
#    'name_sim': 0.25,
#    'name_sim_sw': 0.8235294117647058},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 244822,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.321359045810864,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'City Center Rooms and Apartments',
#    'name_sim': 0.3157894736842105,
#    'name_sim_sw': 0.8125},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1377748,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7733593131866083,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Apartment Angel Plaza 140 m2',
#    'name_sim': 0.24,
#    'name_sim_sw': 0.7878787878787878},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1616498,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.9881224839014736,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Angel City Apartment',
#    'name_sim': 0.5,
#    'name_sim_sw': 0.7878787878787878},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1899786,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 3.0853327445680465,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Bright and Modern Apartment',
#    'name_sim': 0.2,
#    'name_sim_sw': 0.7741935483870968},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1898581,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.5105289404117277,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Nice luxury apartment next to Vistula and Old Town',
#    'name_sim': 0.13953488372093023,
#    'name_sim_sw': 0.7741935483870968},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1904474,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.385853723957767,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Cozy and beautiful apartment in center of Krak\xf3w',
#    'name_sim': 0.2631578947368421,
#    'name_sim_sw': 0.7741935483870968},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1567725,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.028148438344174,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Apartament After Hours',
#    'name_sim': 0.27586206896551724,
#    'name_sim_sw': 0.7647058823529411},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1331097,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.3511364844878904,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Anatom Apartment',
#    'name_sim': 0.46153846153846156,
#    'name_sim_sw': 0.7647058823529411},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1568441,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.5962527324716382,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'New Apartment With a Garden.',
#    'name_sim': 0.23529411764705882,
#    'name_sim_sw': 0.7586206896551724},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1682678,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.283329147248877,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u"Apartment vis'a'vis Wawel Castle",
#    'name_sim': 0.14814814814814814,
#    'name_sim_sw': 0.7586206896551724},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1309588,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.2752240632723402,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Apartment Agnieszki',
#    'name_sim': 0.5,
#    'name_sim_sw': 0.7567567567567568},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1777511,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.9861261280444905,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Aga Apartments',
#    'name_sim': 0.2,
#    'name_sim_sw': 0.75},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1692714,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.789421078871462,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'All In Apartments Siemiradzkiego',
#    'name_sim': 0.24,
#    'name_sim_sw': 0.75},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1689850,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.993209959982821,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Bonerowska 11 - All In Apartments',
#    'name_sim': 0.16666666666666666,
#    'name_sim_sw': 0.75},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1692709,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.42954029289144896,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'All In Apartments Floria\u0144ska',
#    'name_sim': 0.19047619047619047,
#    'name_sim_sw': 0.75},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1775343,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.8580429290151154,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Szlak 21 - All In Apartments',
#    'name_sim': 0.10526315789473684,
#    'name_sim_sw': 0.75},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 860192,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': u'Amstra Luxury Apartments',
#    'dist': 0.5672287108757817,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Old Town Luxury Apartments by Amstra',
#    'name_sim': 0.13793103448275862,
#    'name_sim_sw': 0.7428571428571429},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1821496,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.45693380421386265,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u"L'Appartement sous l'Aigle",
#    'name_sim': 0.30303030303030304,
#    'name_sim_sw': 0.7428571428571429},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 87300,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': u'Artery Hotels',
#    'dist': 0.7530733935551003,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Abella Suites&Apartments by Artery',
#    'name_sim': 0.16666666666666666,
#    'name_sim_sw': 0.7428571428571429},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 18691,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7384123280025389,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Apartamenty Antos',
#    'name_sim': 0.25,
#    'name_sim_sw': 0.7428571428571429},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 741026,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': u'Amstra Luxury Apartments',
#    'dist': 0.8233592203787787,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Wawel Luxury Apartments by Amstra',
#    'name_sim': 0.15384615384615385,
#    'name_sim_sw': 0.7428571428571429},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 684133,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.0200877680877718,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'apartamenty ANGEL CENTRUM',
#    'name_sim': 0.25,
#    'name_sim_sw': 0.7428571428571429},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1711504,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': u'Amstra Luxury Apartments',
#    'dist': 1.0157857530502217,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Wawel Apartments Sarego Residence by Amstra',
#    'name_sim': 0.15384615384615385,
#    'name_sim_sw': 0.7428571428571429},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1736502,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.47424418237693555,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Main Square Luxury Apartments by Amstra',
#    'name_sim': 0.3125,
#    'name_sim_sw': 0.7428571428571429},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1405064,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.390092891041331,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'ApartmentPrestige',
#    'name_sim': 0.3333333333333333,
#    'name_sim_sw': 0.7407407407407407},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1809141,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.0494772816632791,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'BS Apartments Dwernickiego 2',
#    'name_sim': 0.09090909090909091,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1421366,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.8224261538988448,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Royal Town Apartments Sarego 3',
#    'name_sim': 0.23076923076923078,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 571399,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.586834853354856,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Rainbow Apartments 2',
#    'name_sim': 0.2857142857142857,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1350708,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.4692138983204763,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Berry Apartments II',
#    'name_sim': 0.16666666666666666,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1112023,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.3670902244832028,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'777 Apartments 2',
#    'name_sim': 0.0,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1141637,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.8582673915139427,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Concordia Apartments 2',
#    'name_sim': 0.25,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 477337,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.5846682565185017,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Rainbow Apartments 1',
#    'name_sim': 0.2857142857142857,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 550940,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.256004036836819,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Rainbow Apartments 3',
#    'name_sim': 0.25,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1483398,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.14161488793049,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Rainbow Apartments 5',
#    'name_sim': 0.25,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1345961,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.6755469959008306,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'7 Koron - Exclusive Apartments',
#    'name_sim': 0.16666666666666666,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1224225,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.4817613456332434,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Place 4 You Apartments',
#    'name_sim': 0.2222222222222222,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 415014,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.787094508518593,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Abra 2 Apartments',
#    'name_sim': 0.18181818181818182,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1474086,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.035621498202235,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'JT Apartments II',
#    'name_sim': 0.2222222222222222,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1122498,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.13262054096694736,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Szczepa\u0144ska 1 Apartments Sobieski&Soplica',
#    'name_sim': 0.22857142857142856,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 500319,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.5169759285258814,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Miko\u0142ajska 5 Apartments',
#    'name_sim': 0.10526315789473684,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1358184,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.8758678848823044,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Apartment Staszica III',
#    'name_sim': 0.2222222222222222,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1676591,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.3405606583989111,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Loreta\u0144ska Apartments 6',
#    'name_sim': 0.21052631578947367,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1597256,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7495194500002209,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Meyo Apartments II',
#    'name_sim': 0.18181818181818182,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1369846,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 4.095042989687397,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Rainbow Apartments 4',
#    'name_sim': 0.25,
#    'name_sim_sw': 0.7333333333333333},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 396270,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7123109895310227,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Apartament Andy Pandy',
#    'name_sim': 0.21428571428571427,
#    'name_sim_sw': 0.7272727272727273},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1863996,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.1902784720944062,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Alfredo Apartments',
#    'name_sim': 0.2857142857142857,
#    'name_sim_sw': 0.7222222222222222},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1905580,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.3285383416935126,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'GreenApartament',
#    'name_sim': 0.2727272727272727,
#    'name_sim_sw': 0.72},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1670535,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7644149585576422,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Wawel Cracow Old City Apartments - Friendhouse Apartments',
#    'name_sim': 0.11428571428571428,
#    'name_sim_sw': 0.717948717948718},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 89680,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.2137007486063318,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Sodispar Aparthotel & Apartments',
#    'name_sim': 0.15384615384615385,
#    'name_sim_sw': 0.717948717948718},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1308054,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.4598330299796929,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Krak\xf3w Apartments - Friedleina Studio Apartments',
#    'name_sim': 0.25,
#    'name_sim_sw': 0.717948717948718},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1810868,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.2501848075920505,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Krak\xf3w Apartments - Solna Studio & Apartments',
#    'name_sim': 0.21052631578947367,
#    'name_sim_sw': 0.717948717948718},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 320705,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.17524498266370298,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Old Town Apartments S\u0142awkowska',
#    'name_sim': 0.07692307692307693,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1710397,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.4464905895783957,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'OK Apartments Plac Nowy',
#    'name_sim': 0.21052631578947367,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1774104,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.278598971458874,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Kazimierz Friendhouse Apartments',
#    'name_sim': 0.21428571428571427,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1774097,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.221439430858344,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'DesignOmania Apartments with Sauna',
#    'name_sim': 0.32,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 88438,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.07657950885670656,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Golden Lion Apartments Szewska',
#    'name_sim': 0.07692307692307693,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1661117,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.5552439515292126,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Sodispar Mikolajska Old Town Apartments',
#    'name_sim': 0.05714285714285714,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 269052,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': u'Palace Apartments',
#    'dist': 2.4967802651641753,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Palace Apartments Krak\xf3w - Cysters\xf3w',
#    'name_sim': 0.13333333333333333,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1809128,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.4227164988568757,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'BS Apartments Plac Nowy',
#    'name_sim': 0.21052631578947367,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1700974,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7511478746160212,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Royal Town Apartments Zamenhofa',
#    'name_sim': 0.2222222222222222,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 631315,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.263387058837979,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Dream Hostel & Apartments',
#    'name_sim': 0.16666666666666666,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1856357,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.2308843395040185,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Meyo Apartments at Main Square',
#    'name_sim': 0.43478260869565216,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1865155,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.323621574973093,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Erasmus Student Apartments',
#    'name_sim': 0.2727272727272727,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 260728,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.6092124816486595,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Cracow Stay Apartments',
#    'name_sim': 0.2222222222222222,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1700985,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.9869556948254133,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Royal Town Apartments S\u0142owackiego',
#    'name_sim': 0.27586206896551724,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1345812,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.1473166774654255,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Stradonia Serviced Apartments',
#    'name_sim': 0.24,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1823226,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.5917031980264513,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Opera Classic Apartments',
#    'name_sim': 0.1,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 87286,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.8652950624555172,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u"Home in Krakow Silvio's Apartments",
#    'name_sim': 0.18181818181818182,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 704175,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.2382558417903198,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'La Gioia Kazimierz Modern Apartments',
#    'name_sim': 0.13793103448275862,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1327639,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 3.5765279277340056,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Pilotow 87 Apartments',
#    'name_sim': 0.11764705882352941,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1888702,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.1443308045785308,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Old Town Krakow Apartments',
#    'name_sim': 0.09090909090909091,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 187157,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7438816752915997,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Yourplace Victoria Apartments',
#    'name_sim': 0.16,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1365413,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.9113776626322373,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Cracow Old City Apartments - Friendhouse',
#    'name_sim': 0.20689655172413793,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 27788,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': u'Ventus Rosa Group',
#    'dist': 0.46602398716072174,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Ventus Rosa Apartments',
#    'name_sim': 0.3333333333333333,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 356573,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.6790661711170772,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Red Kurka Apartments',
#    'name_sim': 0.125,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1687529,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7822530677193497,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Beyond Apartments Krowoderska',
#    'name_sim': 0.08,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 12956,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.4778378975518311,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Off White Business & Leisure Apartments',
#    'name_sim': 0.16666666666666666,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1421645,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.5759972668508113,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Coffee Apartments Espresso',
#    'name_sim': 0.09090909090909091,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1419561,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.0279517261048468,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Fragola Apartments Old Town',
#    'name_sim': 0.17391304347826086,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1096000,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.995517881936693,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Enigma Apartments Olsza\u0144ska',
#    'name_sim': 0.17391304347826086,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 87727,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7368340710120646,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Red Brick Apartments',
#    'name_sim': 0.125,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1384063,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.46949382286999763,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Royal Town Apartments Czapskich',
#    'name_sim': 0.2222222222222222,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1418208,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.0003088254293144,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Krakow Color Apartments Sarego 24',
#    'name_sim': 0.13793103448275862,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 14891,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7582078587015634,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u"La Gioia Designer's Lofts Luxury Apartments",
#    'name_sim': 0.1111111111111111,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1887279,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.1588892756219384,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Victoria Estate Apartments',
#    'name_sim': 0.18181818181818182,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1393553,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.6793843601548062,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Stylish&Cosy Apartments by Tyzenhauz',
#    'name_sim': 0.20689655172413793,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 88666,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.39896310795301765,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'P&J Apartments Floria\u0144ska',
#    'name_sim': 0.19047619047619047,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1528637,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.01407597887164,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Holiday Apartments Browar Lubicz Krakow Stare Miasto',
#    'name_sim': 0.125,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 12975,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.7347127455625506,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Inkrak Salwator Apartments',
#    'name_sim': 0.09090909090909091,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 261253,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.36590946346208275,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Tutti Frutti Apartments',
#    'name_sim': 0.3157894736842105,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 89947,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.48952979638929844,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Krakow City Apartments',
#    'name_sim': 0.15384615384615385,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 88366,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.112221599130372,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'La Gioia Modern Designed Apartments',
#    'name_sim': 0.14285714285714285,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1389409,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.8490942008622792,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Luxury Apartments Mondrian Old Town',
#    'name_sim': 0.1935483870967742,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 538221,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.6414479300185932,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Mosquito Old Town Apartments',
#    'name_sim': 0.16666666666666666,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1368380,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.213619210896558,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Dietla Street Apartments',
#    'name_sim': 0.2,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1700976,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.4662192766003865,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Royal Town Apartments Pi\u0142sudskiego',
#    'name_sim': 0.3333333333333333,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1717362,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.877733890834859,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Apartments Galla 11',
#    'name_sim': 0.13333333333333333,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1473095,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.14146844890433055,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Boutique Apartments - City Center - The Main Market Square',
#    'name_sim': 0.24390243902439024,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1371479,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.348513771709141,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Lost In Krakow Apartments',
#    'name_sim': 0.1111111111111111,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 402161,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.5240217601701798,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Main Market Square Apartments',
#    'name_sim': 0.4,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1346036,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.3367543197256666,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Apartments Rynek Glowny',
#    'name_sim': 0.21052631578947367,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 604139,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.6763220628550621,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Only Krak\xf3w Apartments',
#    'name_sim': 0.1111111111111111,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 786133,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.7761145933711394,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Enigma Apartments Pawlikowskiego',
#    'name_sim': 0.07142857142857142,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1307784,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 2.156495314649915,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Designomania Apartments - Nadwi\u015bla\u0144ska 11',
#    'name_sim': 0.17142857142857143,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 87033,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 0.15563261402380557,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Old Town Apartments',
#    'name_sim': 0.13333333333333333,
#    'name_sim_sw': 0.7142857142857143},
#   {'amd_id': '01a7d7b5-8cd5-43e9-bbad-b5a6ed75cc87',
#    'bkg_id': 1288853,
#    'chain': u'CLASSIC INTL HOTELS',
#    'chain_bkg': None,
#    'dist': 1.5514475630479831,
#    'name': u'ANTIQUE APARTMENTS',
#    'name_bkg': u'Ska\u0142ka Krakow Apartments',
#    'name_sim': 0.1,
#    'name_sim_sw': 0.7142857142857143},
# ...
#    'dist': 3.014816981180393,
#    'name': u'BAYMONT INN & SUITES HAZELWOOD',
#    'name_bkg': u'Holiday Inn Express Hotel & Suites Hazelwood',
#    'name_sim': 0.8,
#    'name_sim_sw': 0.8095238095238095},
#   {'amd_id': 'fb48d873-362d-4f12-b5ae-de63b39b7308',
#    'bkg_id': 510941,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': None,
#    'dist': 2.2449124497353905,
#    'name': u'BAYMONT INN & SUITES HAZELWOOD',
#    'name_bkg': u'Budget Inn Hazelwood',
#    'name_sim': 0.7111111111111111,
#    'name_sim_sw': 0.7878787878787878}],
#  'fb549f1c-807f-4d2a-8fc1-b04bea16b5c9': [{'amd_id': 'fb549f1c-807f-4d2a-8fc1-b04bea16b5c9',
#    'bkg_id': 518679,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.09460636767769727,
#    'name': u'EXTENDED STAY AMERICA AUSTIN S',
#    'name_bkg': u'Extended Stay America - Austin - Southwest',
#    'name_sim': 0.8823529411764706,
#    'name_sim_sw': 0.8823529411764706}],
#  'fb552ad1-5192-4d40-8b25-dd3f9c493ed9': [{'amd_id': 'fb552ad1-5192-4d40-8b25-dd3f9c493ed9',
#    'bkg_id': 445353,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Holiday Inn Express',
#    'dist': 0.7909937004449874,
#    'name': u'BAYMONT INN & SUITES HUNTSVILL',
#    'name_bkg': u'Holiday Inn Express & Suites Huntsville Airport',
#    'name_sim': 0.7407407407407407,
#    'name_sim_sw': 0.8260869565217391},
#   {'amd_id': 'fb552ad1-5192-4d40-8b25-dd3f9c493ed9',
#    'bkg_id': 466957,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'La Quinta Inn and Suites',
#    'dist': 0.8475893140516103,
#    'name': u'BAYMONT INN & SUITES HUNTSVILL',
#    'name_bkg': u'La Quinta Inn & Suites Huntsville Airport Madison',
#    'name_sim': 0.6557377049180327,
#    'name_sim_sw': 0.8260869565217391},
#   {'amd_id': 'fb552ad1-5192-4d40-8b25-dd3f9c493ed9',
#    'bkg_id': 42837,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Hampton by Hilton',
#    'dist': 0.747713618025802,
#    'name': u'BAYMONT INN & SUITES HUNTSVILL',
#    'name_bkg': u'Hampton Inn Huntsville-Madison',
#    'name_sim': 0.6545454545454545,
#    'name_sim_sw': 0.7272727272727273}],
#  'fc44d1b6-ab58-4049-9386-a675dea3d300': [{'amd_id': 'fc44d1b6-ab58-4049-9386-a675dea3d300',
#    'bkg_id': 469634,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.09949773151210753,
#    'name': u'EXTENDED STAY AMERICA CONV CTR',
#    'name_bkg': u'Extended Stay America - Orlando Convention Center 6443 Westwood',
#    'name_sim': 0.6593406593406593,
#    'name_sim_sw': 0.896551724137931},
#   {'amd_id': 'fc44d1b6-ab58-4049-9386-a675dea3d300',
#    'bkg_id': 22846,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.04842583961211621,
#    'name': u'EXTENDED STAY AMERICA CONV CTR',
#    'name_bkg': u'Extended Stay America - Orlando - Convention Center - Sports Complex',
#    'name_sim': 0.6521739130434783,
#    'name_sim_sw': 0.896551724137931},
#   {'amd_id': 'fc44d1b6-ab58-4049-9386-a675dea3d300',
#    'bkg_id': 184573,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 2.1378272386588817,
#    'name': u'EXTENDED STAY AMERICA CONV CTR',
#    'name_bkg': u'Extended Stay America - Orlando - Convention Center - Universal Blvd',
#    'name_sim': 0.6521739130434783,
#    'name_sim_sw': 0.896551724137931},
#   {'amd_id': 'fc44d1b6-ab58-4049-9386-a675dea3d300',
#    'bkg_id': 279344,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 4.655951126812408,
#    'name': u'EXTENDED STAY AMERICA CONV CTR',
#    'name_bkg': u'Extended Stay America - Orlando - Southpark - Commodity Circle',
#    'name_sim': 0.6511627906976745,
#    'name_sim_sw': 0.8275862068965517},
#   {'amd_id': 'fc44d1b6-ab58-4049-9386-a675dea3d300',
#    'bkg_id': 22852,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 4.405030113987784,
#    'name': u'EXTENDED STAY AMERICA CONV CTR',
#    'name_bkg': u'Extended Stay America - Orlando - Lake Buena Vista',
#    'name_sim': 0.631578947368421,
#    'name_sim_sw': 0.8070175438596491},
#   {'amd_id': 'fc44d1b6-ab58-4049-9386-a675dea3d300',
#    'bkg_id': 469471,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 4.575436607853803,
#    'name': u'EXTENDED STAY AMERICA CONV CTR',
#    'name_bkg': u'Extended Stay America - Orlando - Southpark - Equity Row',
#    'name_sim': 0.6,
#    'name_sim_sw': 0.7931034482758621}],
#  'fc6f3295-b951-40b7-9b38-bcaaf0fe3477': [],
#  'fcb48520-34f1-482a-9131-3ec1d8ca9ee6': [{'amd_id': 'fcb48520-34f1-482a-9131-3ec1d8ca9ee6',
#    'bkg_id': 305168,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Baymont Inn &amp; Suites',
#    'dist': 0.03311327580822944,
#    'name': u'BAYMONT INN & SUITES ALBANY',
#    'name_bkg': u'Baymont Inn and Suites Albany',
#    'name_sim': 1.0,
#    'name_sim_sw': 1.0}],
#  'fcb65c7d-3cb7-4e9c-a64d-8953af5e520d': [{'amd_id': 'fcb65c7d-3cb7-4e9c-a64d-8953af5e520d',
#    'bkg_id': 79750,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Baymont Inn &amp; Suites',
#    'dist': 0.028402855764345595,
#    'name': u'BAYMONT CHICAGO CALUMET CTY',
#    'name_bkg': u'Baymont Inn and Suites Chicago-Calumet City',
#    'name_sim': 0.7931034482758621,
#    'name_sim_sw': 0.9818181818181818}],
#  'fcdc094b-1740-4b90-8e98-5997e56ea7a7': [{'amd_id': 'fcdc094b-1740-4b90-8e98-5997e56ea7a7',
#    'bkg_id': 1826404,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': None,
#    'dist': 2.3602969316554483,
#    'name': u'BAYMONT INN & SUITES SEVIERVIL',
#    'name_bkg': u'',
#    'name_sim': 0.0,
#    'name_sim_sw': 1.0}],
#  'fcec17a3-d676-4c34-9ae0-e927af29c32d': [{'amd_id': 'fcec17a3-d676-4c34-9ae0-e927af29c32d',
#    'bkg_id': 501410,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 1.0840833823747174,
#    'name': u'EXTENDED STAY AMERICA VERNON H',
#    'name_bkg': u'Extended Stay America - Chicago - Vernon Hills - Lincolnshire',
#    'name_sim': 0.7058823529411765,
#    'name_sim_sw': 0.9655172413793104},
#   {'amd_id': 'fcec17a3-d676-4c34-9ae0-e927af29c32d',
#    'bkg_id': 501394,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.933115202772127,
#    'name': u'EXTENDED STAY AMERICA VERNON H',
#    'name_bkg': u'Extended Stay America - Chicago - Vernon Hills - Lake Forest',
#    'name_sim': 0.7142857142857143,
#    'name_sim_sw': 0.9655172413793104},
#   {'amd_id': 'fcec17a3-d676-4c34-9ae0-e927af29c32d',
#    'bkg_id': 501339,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 5.7644640309793225,
#    'name': u'EXTENDED STAY AMERICA VERNON H',
#    'name_bkg': u'Extended Stay America - Chicago - Buffalo Grove - Deerfield',
#    'name_sim': 0.6024096385542169,
#    'name_sim_sw': 0.7719298245614035}],
#  'fe082698-d639-4d31-b2e5-cfe5325ce6fd': [{'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 490565,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Baymont Inn &amp; Suites',
#    'dist': 0.06811079798487438,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Baymont Inn & Suites Billings',
#    'name_sim': 1.0,
#    'name_sim_sw': 1.0},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 490586,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Sleep Inn',
#    'dist': 2.194831808708418,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Sleep Inn Billings',
#    'name_sim': 0.6190476190476191,
#    'name_sim_sw': 0.8823529411764706},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 191403,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Fairfield Inn',
#    'dist': 0.06457453176867187,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Fairfield Inn and Suites Billings',
#    'name_sim': 0.72,
#    'name_sim_sw': 0.8636363636363636},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 372650,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Days Inn',
#    'dist': 1.126473874576825,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Days Inn Billings',
#    'name_sim': 0.7317073170731707,
#    'name_sim_sw': 0.8275862068965517},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 293943,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': None,
#    'dist': 0.722907081305435,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Kelly Inn Billings',
#    'name_sim': 0.6666666666666666,
#    'name_sim_sw': 0.8235294117647058},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 1223159,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Holiday Inn Express',
#    'dist': 3.683699395071163,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Holiday Inn Express Hotel & Suites Billings',
#    'name_sim': 0.7916666666666666,
#    'name_sim_sw': 0.8},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 187718,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Hampton by Hilton',
#    'dist': 3.815430760719251,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Hampton Inn & Suites Billings West I-90',
#    'name_sim': 0.75,
#    'name_sim_sw': 0.8},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 1130981,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'La Quinta Inn and Suites',
#    'dist': 0.9164285722436377,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'La Quinta Inn & Suites Billings',
#    'name_sim': 0.8085106382978723,
#    'name_sim_sw': 0.8},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 287579,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Super 8',
#    'dist': 1.131173008769108,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Super 8 Billings',
#    'name_sim': 0.55,
#    'name_sim_sw': 0.7857142857142857},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 360978,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Howard Johnson',
#    'dist': 1.0302805300489,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Howard Johnson Billings',
#    'name_sim': 0.5405405405405406,
#    'name_sim_sw': 0.7619047619047619},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 184187,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': u'Hampton by Hilton',
#    'dist': 1.707094453234793,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Hampton Inn Billings',
#    'name_sim': 0.7727272727272727,
#    'name_sim_sw': 0.75},
#   {'amd_id': 'fe082698-d639-4d31-b2e5-cfe5325ce6fd',
#    'bkg_id': 1126581,
#    'chain': u'BAYMONT INNS',
#    'chain_bkg': None,
#    'dist': 5.631426208386883,
#    'name': u'BAYMONT INN SUITES BILLINGS',
#    'name_bkg': u'Riversage Billings Inn',
#    'name_sim': 0.5217391304347826,
#    'name_sim_sw': 0.7368421052631579}],
#  'fe9c891c-9098-4d9e-979f-dfe20331bb5c': [{'amd_id': 'fe9c891c-9098-4d9e-979f-dfe20331bb5c',
#    'bkg_id': 515708,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 2.0705534607381684,
#    'name': u'EXTENDED STAY AMERICA SMYRNA',
#    'name_bkg': u'Extended Stay America - Atlanta - Marietta - Interstate N. Pkwy',
#    'name_sim': 0.5476190476190477,
#    'name_sim_sw': 0.9019607843137255},
#   {'amd_id': 'fe9c891c-9098-4d9e-979f-dfe20331bb5c',
#    'bkg_id': 519183,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.12479369398928475,
#    'name': u'EXTENDED STAY AMERICA SMYRNA',
#    'name_bkg': u'Extended Stay America - Atlanta - Cumberland Mall',
#    'name_sim': 0.6301369863013698,
#    'name_sim_sw': 0.8888888888888888},
#   {'amd_id': 'fe9c891c-9098-4d9e-979f-dfe20331bb5c',
#    'bkg_id': 537321,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 3.5600622319569566,
#    'name': u'EXTENDED STAY AMERICA SMYRNA',
#    'name_bkg': u'Extended Stay America - Atlanta - Marietta - Powers Ferry Rd.',
#    'name_sim': 0.5609756097560976,
#    'name_sim_sw': 0.8846153846153846},
#   {'amd_id': 'fe9c891c-9098-4d9e-979f-dfe20331bb5c',
#    'bkg_id': 517534,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 2.474739104910299,
#    'name': u'EXTENDED STAY AMERICA SMYRNA',
#    'name_bkg': u'Extended Stay America - Atlanta - Marietta - Windy Hill',
#    'name_sim': 0.5974025974025974,
#    'name_sim_sw': 0.8620689655172413},
#   {'amd_id': 'fe9c891c-9098-4d9e-979f-dfe20331bb5c',
#    'bkg_id': 513866,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 2.7388311126133322,
#    'name': u'EXTENDED STAY AMERICA SMYRNA',
#    'name_bkg': u'Extended Stay America - Atlanta - Marietta - Wildwood',
#    'name_sim': 0.6133333333333333,
#    'name_sim_sw': 0.8620689655172413},
#   {'amd_id': 'fe9c891c-9098-4d9e-979f-dfe20331bb5c',
#    'bkg_id': 515429,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 2.14374708479145,
#    'name': u'EXTENDED STAY AMERICA SMYRNA',
#    'name_bkg': u'Extended Stay America - Atlanta - Vinings',
#    'name_sim': 0.7076923076923077,
#    'name_sim_sw': 0.8571428571428571}],
#  'fef4596f-f181-434a-b08d-6e1db2943f78': [{'amd_id': 'fef4596f-f181-434a-b08d-6e1db2943f78',
#    'bkg_id': 511704,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.03132225032757779,
#    'name': u'EXTENDED STAY AMERICA EXEC PK',
#    'name_bkg': u'Extended Stay America - Charlotte - Tyvola Rd. - Executive Park',
#    'name_sim': 0.65,
#    'name_sim_sw': 0.8923076923076924},
#   {'amd_id': 'fef4596f-f181-434a-b08d-6e1db2943f78',
#    'bkg_id': 515894,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.8249724531798098,
#    'name': u'EXTENDED STAY AMERICA EXEC PK',
#    'name_bkg': u'Extended Stay America - Charlotte - Tyvola Rd.',
#    'name_sim': 0.6857142857142857,
#    'name_sim_sw': 0.8301886792452831},
#   {'amd_id': 'fef4596f-f181-434a-b08d-6e1db2943f78',
#    'bkg_id': 520245,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 2.579771305387265,
#    'name': u'EXTENDED STAY AMERICA EXEC PK',
#    'name_bkg': u'Extended Stay America - Charlotte - Airport',
#    'name_sim': 0.7936507936507936,
#    'name_sim_sw': 0.7301587301587301}],
#  'ff5b92f0-e0ff-477c-a0e6-b33db026bdb8': [{'amd_id': 'ff5b92f0-e0ff-477c-a0e6-b33db026bdb8',
#    'bkg_id': 521233,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.14367451667766426,
#    'name': u'EXTENDED STAY AMERICA DOWNERS',
#    'name_bkg': u'Extended Stay America - Downers Grove',
#    'name_sim': 0.90625,
#    'name_sim_sw': 1.0},
#   {'amd_id': 'ff5b92f0-e0ff-477c-a0e6-b33db026bdb8',
#    'bkg_id': 515433,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 2.473648698986639,
#    'name': u'EXTENDED STAY AMERICA DOWNERS',
#    'name_bkg': u'Extended Stay America - Chicago - Lombard - Yorktown Center',
#    'name_sim': 0.6829268292682927,
#    'name_sim_sw': 0.8771929824561403},
#   {'amd_id': 'ff5b92f0-e0ff-477c-a0e6-b33db026bdb8',
#    'bkg_id': 515463,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 3.437037944471153,
#    'name': u'EXTENDED STAY AMERICA DOWNERS',
#    'name_bkg': u'Extended Stay America - Chicago - Lisle',
#    'name_sim': 0.75,
#    'name_sim_sw': 0.84},
#   {'amd_id': 'ff5b92f0-e0ff-477c-a0e6-b33db026bdb8',
#    'bkg_id': 501661,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 2.7422900665955283,
#    'name': u'EXTENDED STAY AMERICA DOWNERS',
#    'name_bkg': u'Extended Stay America - Chicago - Lombard - Oakbrook',
#    'name_sim': 0.64,
#    'name_sim_sw': 0.84}],
#  'ff9d1775-7757-41b8-a819-62e6dd0bdde6': [{'amd_id': 'ff9d1775-7757-41b8-a819-62e6dd0bdde6',
#    'bkg_id': 521047,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': u'Extended Stay America',
#    'dist': 0.0731867295830627,
#    'name': u'EXTENDED STAY AMERICA EL SEGUN',
#    'name_bkg': u'Extended Stay America - Los Angeles - LAX Airport - El Segundo',
#    'name_sim': 0.7407407407407407,
#    'name_sim_sw': 0.967741935483871},
#   {'amd_id': 'ff9d1775-7757-41b8-a819-62e6dd0bdde6',
#    'bkg_id': 1834371,
#    'chain': u'EXTENDED STAY',
#    'chain_bkg': None,
#    'dist': 2.9424499309987584,
#    'name': u'EXTENDED STAY AMERICA EL SEGUN',
#    'name_bkg': u'El Segundo Inn',
#    'name_sim': 0.36363636363636365,
#    'name_sim_sw': 0.7272727272727273}]}

# %% [markdown]
# # 4. extract features

# %%
import itertools
def concatenate(ll):
    return list(itertools.chain.from_iterable(ll))

# %%
mdf = pd.DataFrame(concatenate(candidates.values()))

# %%
def norm_text(column):
    return column.astype(unicode).fillna('').apply(normalize).astype(unicode)

# %%
def row_name_included(row):
    n = normalize(row['name']).replace(' ', '')    
    nb = normalize(row['name_bkg']).replace(' ', '')
    if not n:
        return False
    if not nb:
        return False
    return (n in nb) or (nb in n)    

def row_chain_included(row):
    n = normalize(row['chain']).replace(' ', '')    
    nb = normalize(row['chain_bkg']).replace(' ', '')
    if not n:
        return False
    if not nb:
        return False
    return (n in nb) or (nb in n)

def row_chain_sim(row):
    return get_name_sim(row['chain'], row['chain_bkg'])

def row_chain_sim_sw(row):
    return get_name_sim(row['chain'], row['chain_bkg'], swap_words=True)

# %% [markdown]
# # 5. use classifier to pick valid matches

# %%
from scipy.sparse import hstack

# %%
with open('rdf_matches.pickle','rb') as f:
    clf = pickle.load(f)

# %%
def load_chain_encoders():
    with open('chain_encoders.pickle', 'rb') as f:
        le_chain, ohe, le_chain_bk, ohe_bk = pickle.load(f)
    return le_chain, ohe, le_chain_bk, ohe_bk

# %%
def add_features(X):
    for col in 'name name_bkg chain chain_bkg'.split():
        X[col] = norm_text(X[col])
    
    X['name_included'] = X.apply(row_name_included, axis=1)
    X['chain_included'] = X.apply(row_chain_included, axis=1)

    X['chain_sim'] = X.apply(row_chain_sim, axis=1)
    X['chain_sim_sw'] = X.apply(row_chain_sim_sw, axis=1)
    
    return X

# %%
def pre_process(X):    
    X.chain.fillna('', inplace=True)
    X.chain_bkg.fillna('', inplace=True)
    X.name.fillna('', inplace=True)
    X.name_bkg.fillna('', inplace=True)
    X.chain_included.fillna(False, inplace=True)
    X.name_included.fillna(False, inplace=True)

    Xnum = X[[u'dist', u'name_sim', u'name_sim_sw', u'chain_sim', u'chain_sim_sw',
           u'name_included', u'chain_included']]

    Xcat = X[[u'chain', u'chain_bkg']]

    le_chain, ohe, le_chain_bk, ohe_bk = load_chain_encoders()
    Xchain = le_chain.transform(X.chain)
    Xchain = ohe.transform(Xchain.reshape(-1,1))

    Xchain_bkg = le_chain_bk.transform(X.chain_bkg)
    Xchain_bkg = ohe_bk.transform(Xchain_bkg.reshape(-1,1))

    X = hstack((Xnum.astype(float), Xchain, Xchain_bkg))
    
    return X

# %%
retrain_set = []
retrain_labels = []
matches = {}

for amd_id, match_cands in candidates.items():
    # filter candidates with classifier
    if not match_cands:
        continue
    X = pd.DataFrame(match_cands)
    X = add_features(X)
    X['match'] = clf.predict(pre_process(X))
    X = X[X.match == 1]
    
    ncands = X.shape[0]
    
    if ncands == 0:
        match = None
    elif ncands == 1:
        match = X.loc[0,:]
    else:        
        # pick best if many different
        sums = {}
        compare_cols = 'name_sim_sw name_included chain_included chain_sim_sw'.split()
        for c in compare_cols:
            sums[c] = X[c].sum()
        sums['inv_dist'] = sum(1/d for d in X.dist.notnull())
        
        def score_row(row):
            score = sum(row[c]/sums[c] for c in compare_cols if sums[c])
            if row['dist']:
                score += (1 / row['dist']) / sums['inv_dist']
            else:
                score += 1
            return score
        
        X.score = X.apply(score_row, axis=1)
        ind_max = X.score.argmax()
        match = X.loc[ind_max,:]

        # mark the 'losers' as non-matches for future re-training
        for i in X.index:
            if i != ind_max:
                d = X.loc[i,:].to_dict()
                retrain_set.append(d)
                retrain_labels.append(0)
    
    if match is not None:
        d = match.to_dict()
        retrain_set.append(d)
        retrain_labels.append(1)
        matches[r['amd_id']] = r['bkg_id']
